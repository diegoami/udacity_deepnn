# %% [markdown]
# Deep Learning
# =============
#
# Assignment 1
# ------------
#
# The objective of this assignment is to learn about simple data curation practices, and familiarize you with some of the data we'll be reusing later.
#
# This notebook uses the [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) dataset to be used with python experiments. This dataset is designed to look like the classic [MNIST](http://yann.lecun.com/exdb/mnist/) dataset, while looking a little more like real data: it's a harder task, and the data is a lot less 'clean' than MNIST.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import matplotlib.pyplot as plt
import numpy as np
import os

import sys
import tarfile
from IPython.display import display, Image
from scipy import ndimage
from sklearn.linear_model import LogisticRegression
from six.moves.urllib.request import urlretrieve
from six.moves import cPickle as pickle

# Config the matplotlib backend as plotting inline in IPython
# %matplotlib inline

# %% [markdown]
# First, we'll download the dataset to our local machine. The data consists of characters rendered in a variety of fonts on a 28x28 image. The labels are limited to 'A' through 'J' (10 classes). The training set has about 500k and the testset 19000 labeled examples. Given these sizes, it should be possible to train models quickly on any machine.

# %%
url = 'https://commondatastorage.googleapis.com/books1000/'
last_percent_reported = None
data_root = '.' # Change me to store data elsewhere

def download_progress_hook(count, blockSize, totalSize):
  """A hook to report the progress of a download. This is mostly intended for users with
  slow internet connections. Reports every 5% change in download progress.
  """
  global last_percent_reported
  percent = int(count * blockSize * 100 / totalSize)

  if last_percent_reported != percent:
    if percent % 5 == 0:
      sys.stdout.write("%s%%" % percent)
      sys.stdout.flush()
    else:
      sys.stdout.write(".")
      sys.stdout.flush()
      
    last_percent_reported = percent
        
def maybe_download(filename, expected_bytes, force=False):
  """Download a file if not present, and make sure it's the right size."""
  dest_filename = os.path.join(data_root, filename)
  if force or not os.path.exists(dest_filename):
    print('Attempting to download:', filename) 
    filename, _ = urlretrieve(url + filename, dest_filename, reporthook=download_progress_hook)
    print('\nDownload Complete!')
  statinfo = os.stat(dest_filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', dest_filename)
  else:
    raise Exception(
      'Failed to verify ' + dest_filename + '. Can you get to it with a browser?')
  return dest_filename

train_filename = maybe_download('notMNIST_large.tar.gz', 247336696)
test_filename = maybe_download('notMNIST_small.tar.gz', 8458043)
# Out:
# Attempting to download: notMNIST_large.tar.gz
# 0%....5%....
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-5c88a7581c1f> in <module>()
#      35   return dest_filename
#      36
# ---> 37 train_filename = maybe_download('notMNIST_large.tar.gz', 247336696)
#      38 test_filename = maybe_download('notMNIST_small.tar.gz', 8458043)
#
# <ipython-input-2-5c88a7581c1f> in maybe_download(filename, expected_bytes, force)
#      25   if force or not os.path.exists(dest_filename):
#      26     print('Attempting to download:', filename)
# ---> 27     filename, _ = urlretrieve(url + filename, dest_filename, reporthook=download_progress_hook)
#      28     print('\nDownload Complete!')
#      29   statinfo = os.stat(dest_filename)
#
# ~/anaconda3/envs/datacamp/lib/python3.6/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     275
#     276             while True:
# --> 277                 block = fp.read(bs)
#     278                 if not block:
#     279                     break
#
# ~/anaconda3/envs/datacamp/lib/python3.6/http/client.py in read(self, amt)
#     447             # Amount is given, implement using readinto
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#     451         else:
#
# ~/anaconda3/envs/datacamp/lib/python3.6/http/client.py in readinto(self, b)
#     491         # connection, and the user is reading more bytes than will be provided
#     492         # (for example, reading in 1k chunks)
# --> 493         n = self.fp.readinto(b)
#     494         if not n and b:
#     495             # Ideally, we would raise IncompleteRead if the content-length
#
# ~/anaconda3/envs/datacamp/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/anaconda3/envs/datacamp/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1000                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1001                   self.__class__)
# -> 1002             return self.read(nbytes, buffer)
#    1003         else:
#    1004             return socket.recv_into(self, buffer, nbytes, flags)
#
# ~/anaconda3/envs/datacamp/lib/python3.6/ssl.py in read(self, len, buffer)
#     863             raise ValueError("Read on closed or unwrapped SSL socket.")
#     864         try:
# --> 865             return self._sslobj.read(len, buffer)
#     866         except SSLError as x:
#     867             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# ~/anaconda3/envs/datacamp/lib/python3.6/ssl.py in read(self, len, buffer)
#     623         """
#     624         if buffer is not None:
# --> 625             v = self._sslobj.read(len, buffer)
#     626         else:
#     627             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# Extract the dataset from the compressed .tar.gz file.
# This should give you a set of directories, labeled A through J.

# %%
num_classes = 10
np.random.seed(133)

def maybe_extract(filename, force=False):
  root = os.path.splitext(os.path.splitext(filename)[0])[0]  # remove .tar.gz
  if os.path.isdir(root) and not force:
    # You may override by setting force=True.
    print('%s already present - Skipping extraction of %s.' % (root, filename))
  else:
    print('Extracting data for %s. This may take a while. Please wait.' % root)
    tar = tarfile.open(filename)
    sys.stdout.flush()
    tar.extractall(data_root)
    tar.close()
  data_folders = [
    os.path.join(root, d) for d in sorted(os.listdir(root))
    if os.path.isdir(os.path.join(root, d))]
  if len(data_folders) != num_classes:
    raise Exception(
      'Expected %d folders, one per class. Found %d instead.' % (
        num_classes, len(data_folders)))
  print(data_folders)
  return data_folders
  
train_folders = maybe_extract(train_filename)
test_folders = maybe_extract(test_filename)
# Out:
# ./notMNIST_large already present - Skipping extraction of ./notMNIST_large.tar.gz.
# ['./notMNIST_large/A', './notMNIST_large/B', './notMNIST_large/C', './notMNIST_large/D', './notMNIST_large/E', './notMNIST_large/F', './notMNIST_large/G', './notMNIST_large/H', './notMNIST_large/I', './notMNIST_large/J']
# ./notMNIST_small already present - Skipping extraction of ./notMNIST_small.tar.gz.
# ['./notMNIST_small/A', './notMNIST_small/B', './notMNIST_small/C', './notMNIST_small/D', './notMNIST_small/E', './notMNIST_small/F', './notMNIST_small/G', './notMNIST_small/H', './notMNIST_small/I', './notMNIST_small/J']

# %% [markdown]
# ---
# Problem 1
# ---------
#
# Let's take a peek at some of the data to make sure it looks sensible. Each exemplar should be an image of a character A through J rendered in a different font. Display a sample of the images that we just downloaded. Hint: you can use the package IPython.display.
#
# ---

# %%
from IPython.display import Image
image_links = ['notMNIST_small/A/MDEtMDEtMDAudHRm.png',
                'notMNIST_small/A/Nng3b2N0IEFsdGVybmF0ZSBFeHRyYUxpZ2h0LnR0Zg==.png',
                'notMNIST_small/A/Q2dGaWVkbGVyR290aGljLUJvbGQudHRm.png' ]
print(image_links)
for image_link in image_links:
    display(Image(image_link))
# Out:
# ['notMNIST_small/A/MDEtMDEtMDAudHRm.png', 'notMNIST_small/A/Nng3b2N0IEFsdGVybmF0ZSBFeHRyYUxpZ2h0LnR0Zg==.png', 'notMNIST_small/A/Q2dGaWVkbGVyR290aGljLUJvbGQudHRm.png']

# %% [markdown]
# Now let's load the data in a more manageable format. Since, depending on your computer setup you might not be able to fit it all in memory, we'll load each class into a separate dataset, store them on disk and curate them independently. Later we'll merge them into a single dataset of manageable size.
#
# We'll convert the entire dataset into a 3D array (image index, x, y) of floating point values, normalized to have approximately zero mean and standard deviation ~0.5 to make training easier down the road.
#
# A few images might not be readable, we'll just skip them.

# %%
image_size = 28  # Pixel width and height.
pixel_depth = 255.0  # Number of levels per pixel.

def load_letter(folder, min_num_images):
  """Load the data for a single letter label."""
  image_files = os.listdir(folder)
  dataset = np.ndarray(shape=(len(image_files), image_size, image_size),
                         dtype=np.float32)
  print(folder)
  num_images = 0
  for image in image_files:
    image_file = os.path.join(folder, image)
    try:
      image_data = (ndimage.imread(image_file).astype(float) - 
                    pixel_depth / 2) / pixel_depth
      if image_data.shape != (image_size, image_size):
        raise Exception('Unexpected image shape: %s' % str(image_data.shape))
      dataset[num_images, :, :] = image_data
      num_images = num_images + 1
    except IOError as e:
      print('Could not read:', image_file, ':', e, '- it\'s ok, skipping.')
    
  dataset = dataset[0:num_images, :, :]
  if num_images < min_num_images:
    raise Exception('Many fewer images than expected: %d < %d' %
                    (num_images, min_num_images))
    
  print('Full dataset tensor:', dataset.shape)
  print('Mean:', np.mean(dataset))
  print('Standard deviation:', np.std(dataset))
  return dataset
        
def maybe_pickle(data_folders, min_num_images_per_class, force=False):
  dataset_names = []
  for folder in data_folders:
    set_filename = folder + '.pickle'
    dataset_names.append(set_filename)
    if os.path.exists(set_filename) and not force:
      # You may override by setting force=True.
      print('%s already present - Skipping pickling.' % set_filename)
    else:
      print('Pickling %s.' % set_filename)
      dataset = load_letter(folder, min_num_images_per_class)
      try:
        with open(set_filename, 'wb') as f:
          pickle.dump(dataset, f, pickle.HIGHEST_PROTOCOL)
      except Exception as e:
        print('Unable to save data to', set_filename, ':', e)
  
  return dataset_names

train_datasets = maybe_pickle(train_folders, 45000)
test_datasets = maybe_pickle(test_folders, 1800)

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Let's verify that the data still looks good. Displaying a sample of the labels and images from the ndarray. Hint: you can use matplotlib.pyplot.
#
# ---

# %%
import matplotlib.pyplot as plt
letter = load_letter('notMNIST_small/A',10)

#plt.plot(letter[0])

letter[0].shape
plt.matshow(letter[0])
# Out:
# notMNIST_small/A
# Could not read: notMNIST_small/A/RGVtb2NyYXRpY2FCb2xkT2xkc3R5bGUgQm9sZC50dGY=.png : cannot identify image file 'notMNIST_small/A/RGVtb2NyYXRpY2FCb2xkT2xkc3R5bGUgQm9sZC50dGY=.png' - it's ok, skipping.
# Full dataset tensor: (1872, 28, 28)
# Mean: -0.132626
# Standard deviation: 0.445128

# %% [markdown]
# ---
# Problem 3
# ---------
# Another check: we expect the data to be balanced across classes. Verify that.
#
# ---

# %%
train_folders
for folder in train_folders:
    letter = load_letter(folder ,10)
    print(letter.shape)
# Out:
# ./notMNIST_large/A
# Could not read: ./notMNIST_large/A/SG90IE11c3RhcmQgQlROIFBvc3Rlci50dGY=.png : cannot identify image file './notMNIST_large/A/SG90IE11c3RhcmQgQlROIFBvc3Rlci50dGY=.png' - it's ok, skipping.
# Could not read: ./notMNIST_large/A/Um9tYW5hIEJvbGQucGZi.png : cannot identify image file './notMNIST_large/A/Um9tYW5hIEJvbGQucGZi.png' - it's ok, skipping.
# Could not read: ./notMNIST_large/A/RnJlaWdodERpc3BCb29rSXRhbGljLnR0Zg==.png : cannot identify image file './notMNIST_large/A/RnJlaWdodERpc3BCb29rSXRhbGljLnR0Zg==.png' - it's ok, skipping.
# Full dataset tensor: (52909, 28, 28)
# Mean: -0.12825
# Standard deviation: 0.443121
# (52909, 28, 28)
# ./notMNIST_large/B
# Could not read: ./notMNIST_large/B/TmlraXNFRi1TZW1pQm9sZEl0YWxpYy5vdGY=.png : cannot identify image file './notMNIST_large/B/TmlraXNFRi1TZW1pQm9sZEl0YWxpYy5vdGY=.png' - it's ok, skipping.
# Full dataset tensor: (52911, 28, 28)
# Mean: -0.00756304
# Standard deviation: 0.454492
# (52911, 28, 28)
# ./notMNIST_large/C
# Full dataset tensor: (52912, 28, 28)
# Mean: -0.142258
# Standard deviation: 0.439806
# (52912, 28, 28)
# ./notMNIST_large/D
# Could not read: ./notMNIST_large/D/VHJhbnNpdCBCb2xkLnR0Zg==.png : cannot identify image file './notMNIST_large/D/VHJhbnNpdCBCb2xkLnR0Zg==.png' - it's ok, skipping.
# Full dataset tensor: (52911, 28, 28)
# Mean: -0.0573678
# Standard deviation: 0.455648
# (52911, 28, 28)
# ./notMNIST_large/E
# Full dataset tensor: (52912, 28, 28)
# Mean: -0.0698989
# Standard deviation: 0.452942
# (52912, 28, 28)
# ./notMNIST_large/F
# Full dataset tensor: (52912, 28, 28)
# Mean: -0.125583
# Standard deviation: 0.447089
# (52912, 28, 28)
# ./notMNIST_large/G
# Full dataset tensor: (52912, 28, 28)
# Mean: -0.0945816
# Standard deviation: 0.44624
# (52912, 28, 28)
# ./notMNIST_large/H
# Full dataset tensor: (52912, 28, 28)
# Mean: -0.0685221
# Standard deviation: 0.454231
# (52912, 28, 28)
# ./notMNIST_large/I
# Full dataset tensor: (52912, 28, 28)
# Mean: 0.0307863
# Standard deviation: 0.468899
# (52912, 28, 28)
# ./notMNIST_large/J
# Full dataset tensor: (52911, 28, 28)
# Mean: -0.153359
# Standard deviation: 0.443656
# (52911, 28, 28)

# %% [markdown]
# Merge and prune the training data as needed. Depending on your computer setup, you might not be able to fit it all in memory, and you can tune `train_size` as needed. The labels will be stored into a separate array of integers 0 through 9.
#
# Also create a validation dataset for hyperparameter tuning.

# %%
def make_arrays(nb_rows, img_size):
  if nb_rows:
    dataset = np.ndarray((nb_rows, img_size, img_size), dtype=np.float32)
    labels = np.ndarray(nb_rows, dtype=np.int32)
  else:
    dataset, labels = None, None
  return dataset, labels

def merge_datasets(pickle_files, train_size, valid_size=0):
  num_classes = len(pickle_files)
  valid_dataset, valid_labels = make_arrays(valid_size, image_size)
  train_dataset, train_labels = make_arrays(train_size, image_size)
  vsize_per_class = valid_size // num_classes
  tsize_per_class = train_size // num_classes
    
  start_v, start_t = 0, 0
  end_v, end_t = vsize_per_class, tsize_per_class
  end_l = vsize_per_class+tsize_per_class
  for label, pickle_file in enumerate(pickle_files):       
    try:
      with open(pickle_file, 'rb') as f:
        letter_set = pickle.load(f)
        # let's shuffle the letters to have random validation and training set
        np.random.shuffle(letter_set)
        if valid_dataset is not None:
          valid_letter = letter_set[:vsize_per_class, :, :]
          valid_dataset[start_v:end_v, :, :] = valid_letter
          valid_labels[start_v:end_v] = label
          start_v += vsize_per_class
          end_v += vsize_per_class
                    
        train_letter = letter_set[vsize_per_class:end_l, :, :]
        train_dataset[start_t:end_t, :, :] = train_letter
        train_labels[start_t:end_t] = label
        start_t += tsize_per_class
        end_t += tsize_per_class
    except Exception as e:
      print('Unable to process data from', pickle_file, ':', e)
      raise
    
  return valid_dataset, valid_labels, train_dataset, train_labels
            
            
train_size = 200000
valid_size = 10000
test_size = 10000

valid_dataset, valid_labels, train_dataset, train_labels = merge_datasets(
  train_datasets, train_size, valid_size)
_, _, test_dataset, test_labels = merge_datasets(test_datasets, test_size)

print('Training:', train_dataset.shape, train_labels.shape)
print('Validation:', valid_dataset.shape, valid_labels.shape)
print('Testing:', test_dataset.shape, test_labels.shape)
# Out:
# Training: (200000, 28, 28) (200000,)
# Validation: (10000, 28, 28) (10000,)
# Testing: (10000, 28, 28) (10000,)

# %% [markdown]
# Next, we'll randomize the data. It's important to have the labels well shuffled for the training and test distributions to match.

# %%
def randomize(dataset, labels):
  permutation = np.random.permutation(labels.shape[0])
  shuffled_dataset = dataset[permutation,:,:]
  shuffled_labels = labels[permutation]
  return shuffled_dataset, shuffled_labels
train_dataset, train_labels = randomize(train_dataset, train_labels)
test_dataset, test_labels = randomize(test_dataset, test_labels)
valid_dataset, valid_labels = randomize(valid_dataset, valid_labels)

# %% [markdown]
# ---
# Problem 4
# ---------
# Convince yourself that the data is still good after shuffling!
#
# ---

# %%
print(train_dataset.shape, train_labels.shape) 
print(test_dataset.shape, test_labels.shape)
print(valid_dataset.shape, valid_labels.shape)
# Out:
# (200000, 28, 28) (200000,)
# (10000, 28, 28) (10000,)
# (10000, 28, 28) (10000,)

# %% [markdown]
# Finally, let's save the data for later reuse:

# %%
pickle_file = os.path.join(data_root, 'notMNIST.pickle')

try:
  f = open(pickle_file, 'wb')
  save = {
    'train_dataset': train_dataset,
    'train_labels': train_labels,
    'valid_dataset': valid_dataset,
    'valid_labels': valid_labels,
    'test_dataset': test_dataset,
    'test_labels': test_labels,
    }
  pickle.dump(save, f, pickle.HIGHEST_PROTOCOL)
  f.close()
except Exception as e:
  print('Unable to save data to', pickle_file, ':', e)
  raise

# %%
statinfo = os.stat(pickle_file)
print('Compressed pickle size:', statinfo.st_size)
# Out:
# Compressed pickle size: 690800506

# %% [markdown]
# ---
# Problem 5
# ---------
#
# By construction, this dataset might contain a lot of overlapping samples, including training data that's also contained in the validation and test set! Overlap between training and test can skew the results if you expect to use your model in an environment where there is never an overlap, but are actually ok if you expect to see training samples recur when you use it.
# Measure how much overlap there is between training, validation and test samples.
#
# Optional questions:
# - What about near duplicates between datasets? (images that are almost identical)
# - Create a sanitized validation and test set, and compare your accuracy on those in subsequent assignments.
# ---

# %%
import os,pickle
data_root = '..'
import numpy as np
pickle_file = os.path.join(data_root, 'notMNIST.pickle')
f = open(pickle_file, 'rb')
pkl = pickle.load(f)
print(pkl.keys())
 #print(pkl['train_dataset'])
 #print(pkl['test_dataset'])
train_dataset = pkl['train_dataset'][:20000]
test_dataset = pkl['test_dataset'][:1000]
#print(train_dataset.shape)
#print(test_dataset[0])
#test_flattened = test_dataset.reshape(10,28*28)
#print(test_flattened.shape)
#print(test_flattened[0])
#train_flattened = train_dataset.flatten() 
#print(train_flattened.shape)

print(test_dataset.shape)
for i in range(test_dataset.shape[0]):
    letter = test_dataset[i]
    for j in range(train_dataset.shape[0]):
        letter_c =  train_dataset[j]
        if (np.all(letter == letter_c)):
            print("TRAIN[{}] == TEST[{}]".format(j,i))
    #print(letter.shape)
    #result = np.searchsorted(letter, train_flattened)
    #result.
# Out:
# dict_keys(['train_dataset', 'train_labels', 'valid_dataset', 'valid_labels', 'test_dataset', 'test_labels'])
# (1000, 28, 28)
# TRAIN[8336] == TEST[27]
# TRAIN[26] == TEST[32]
# TRAIN[293] == TEST[32]
# TRAIN[445] == TEST[32]
# TRAIN[468] == TEST[32]
# TRAIN[543] == TEST[32]
# TRAIN[951] == TEST[32]
# TRAIN[1013] == TEST[32]
# TRAIN[1212] == TEST[32]
# TRAIN[1288] == TEST[32]
# TRAIN[1535] == TEST[32]
# TRAIN[1560] == TEST[32]
# TRAIN[1599] == TEST[32]
# TRAIN[1600] == TEST[32]
# TRAIN[1700] == TEST[32]
# TRAIN[1810] == TEST[32]
# TRAIN[1933] == TEST[32]
# TRAIN[1988] == TEST[32]
# TRAIN[1992] == TEST[32]
# TRAIN[2039] == TEST[32]
# TRAIN[2046] == TEST[32]
# TRAIN[2066] == TEST[32]
# TRAIN[2275] == TEST[32]
# TRAIN[2333] == TEST[32]
# TRAIN[2396] == TEST[32]
# TRAIN[2486] == TEST[32]
# TRAIN[2603] == TEST[32]
# TRAIN[2625] == TEST[32]
# TRAIN[2656] == TEST[32]
# TRAIN[2843] == TEST[32]
# TRAIN[2880] == TEST[32]
# TRAIN[2959] == TEST[32]
# TRAIN[3040] == TEST[32]
# TRAIN[3217] == TEST[32]
# TRAIN[3268] == TEST[32]
# TRAIN[3475] == TEST[32]
# TRAIN[3477] == TEST[32]
# TRAIN[3494] == TEST[32]
# TRAIN[3616] == TEST[32]
# TRAIN[3660] == TEST[32]
# TRAIN[3709] == TEST[32]
# TRAIN[3749] == TEST[32]
# TRAIN[3810] == TEST[32]
# TRAIN[3907] == TEST[32]
# TRAIN[3994] == TEST[32]
# TRAIN[4045] == TEST[32]
# TRAIN[4046] == TEST[32]
# TRAIN[4226] == TEST[32]
# TRAIN[4287] == TEST[32]
# TRAIN[4437] == TEST[32]
# TRAIN[4449] == TEST[32]
# TRAIN[4563] == TEST[32]
# TRAIN[4836] == TEST[32]
# TRAIN[4942] == TEST[32]
# TRAIN[4989] == TEST[32]
# TRAIN[5032] == TEST[32]
# TRAIN[5147] == TEST[32]
# TRAIN[5297] == TEST[32]
# TRAIN[5477] == TEST[32]
# TRAIN[5496] == TEST[32]
# TRAIN[5500] == TEST[32]
# TRAIN[5509] == TEST[32]
# TRAIN[5511] == TEST[32]
# TRAIN[5524] == TEST[32]
# TRAIN[5542] == TEST[32]
# TRAIN[5645] == TEST[32]
# TRAIN[5653] == TEST[32]
# TRAIN[5654] == TEST[32]
# TRAIN[5795] == TEST[32]
# TRAIN[6083] == TEST[32]
# TRAIN[6092] == TEST[32]
# TRAIN[6123] == TEST[32]
# TRAIN[6139] == TEST[32]
# TRAIN[6458] == TEST[32]
# TRAIN[6475] == TEST[32]
# TRAIN[6784] == TEST[32]
# TRAIN[7092] == TEST[32]
# TRAIN[7119] == TEST[32]
# TRAIN[7244] == TEST[32]
# TRAIN[7255] == TEST[32]
# TRAIN[7273] == TEST[32]
# TRAIN[7514] == TEST[32]
# TRAIN[7686] == TEST[32]
# TRAIN[8012] == TEST[32]
# TRAIN[8023] == TEST[32]
# TRAIN[8085] == TEST[32]
# TRAIN[8131] == TEST[32]
# TRAIN[8145] == TEST[32]
# TRAIN[8148] == TEST[32]
# TRAIN[8165] == TEST[32]
# TRAIN[8240] == TEST[32]
# TRAIN[8290] == TEST[32]
# TRAIN[8332] == TEST[32]
# TRAIN[8520] == TEST[32]
# TRAIN[8713] == TEST[32]
# TRAIN[8813] == TEST[32]
# TRAIN[8815] == TEST[32]
# TRAIN[8931] == TEST[32]
# TRAIN[9013] == TEST[32]
# TRAIN[9204] == TEST[32]
# TRAIN[9278] == TEST[32]
# TRAIN[9341] == TEST[32]
# TRAIN[9362] == TEST[32]
# TRAIN[9414] == TEST[32]
# TRAIN[9606] == TEST[32]
# TRAIN[9640] == TEST[32]
# TRAIN[9786] == TEST[32]
# TRAIN[9816] == TEST[32]
# TRAIN[9869] == TEST[32]
# TRAIN[9960] == TEST[32]
# TRAIN[10136] == TEST[32]
# TRAIN[10167] == TEST[32]
# TRAIN[10342] == TEST[32]
# TRAIN[10380] == TEST[32]
# TRAIN[10426] == TEST[32]
# TRAIN[10448] == TEST[32]
# TRAIN[10510] == TEST[32]
# TRAIN[10547] == TEST[32]
# TRAIN[10665] == TEST[32]
# TRAIN[10681] == TEST[32]
# TRAIN[10716] == TEST[32]
# TRAIN[10722] == TEST[32]
# TRAIN[10994] == TEST[32]
# TRAIN[10996] == TEST[32]
# TRAIN[11150] == TEST[32]
# TRAIN[11232] == TEST[32]
# TRAIN[11354] == TEST[32]
# TRAIN[11460] == TEST[32]
# TRAIN[11575] == TEST[32]
# TRAIN[11727] == TEST[32]
# TRAIN[11898] == TEST[32]
# TRAIN[12362] == TEST[32]
# TRAIN[12451] == TEST[32]
# TRAIN[12669] == TEST[32]
# TRAIN[12738] == TEST[32]
# TRAIN[12954] == TEST[32]
# TRAIN[12984] == TEST[32]
# TRAIN[12986] == TEST[32]
# TRAIN[13230] == TEST[32]
# TRAIN[13430] == TEST[32]
# TRAIN[13523] == TEST[32]
# TRAIN[13592] == TEST[32]
# TRAIN[13777] == TEST[32]
# TRAIN[13789] == TEST[32]
# TRAIN[13855] == TEST[32]
# TRAIN[13995] == TEST[32]
# TRAIN[14054] == TEST[32]
# TRAIN[14111] == TEST[32]
# TRAIN[14168] == TEST[32]
# TRAIN[14274] == TEST[32]
# TRAIN[14415] == TEST[32]
# TRAIN[14768] == TEST[32]
# TRAIN[14777] == TEST[32]
# TRAIN[15372] == TEST[32]
# TRAIN[15394] == TEST[32]
# TRAIN[15450] == TEST[32]
# TRAIN[15466] == TEST[32]
# TRAIN[15481] == TEST[32]
# TRAIN[15578] == TEST[32]
# TRAIN[15638] == TEST[32]
# TRAIN[15746] == TEST[32]
# TRAIN[15914] == TEST[32]
# TRAIN[15958] == TEST[32]
# TRAIN[15983] == TEST[32]
# TRAIN[16138] == TEST[32]
# TRAIN[16265] == TEST[32]
# TRAIN[16294] == TEST[32]
# TRAIN[16448] == TEST[32]
# TRAIN[16508] == TEST[32]
# TRAIN[16690] == TEST[32]
# TRAIN[16731] == TEST[32]
# TRAIN[16886] == TEST[32]
# TRAIN[17067] == TEST[32]
# TRAIN[17159] == TEST[32]
# TRAIN[17182] == TEST[32]
# TRAIN[17191] == TEST[32]
# TRAIN[17222] == TEST[32]
# TRAIN[17295] == TEST[32]
# TRAIN[17673] == TEST[32]
# TRAIN[17725] == TEST[32]
# TRAIN[17737] == TEST[32]
# TRAIN[17828] == TEST[32]
# TRAIN[17874] == TEST[32]
# TRAIN[18185] == TEST[32]
# TRAIN[18208] == TEST[32]
# TRAIN[18294] == TEST[32]
# TRAIN[18327] == TEST[32]
# TRAIN[18493] == TEST[32]
# TRAIN[18511] == TEST[32]
# TRAIN[18541] == TEST[32]
# TRAIN[18629] == TEST[32]
# TRAIN[18983] == TEST[32]
# TRAIN[19086] == TEST[32]
# TRAIN[19160] == TEST[32]
# TRAIN[19263] == TEST[32]
# TRAIN[19286] == TEST[32]
# TRAIN[19308] == TEST[32]
# TRAIN[19465] == TEST[32]
# TRAIN[19584] == TEST[32]
# TRAIN[19609] == TEST[32]
# TRAIN[19690] == TEST[32]
# TRAIN[19848] == TEST[32]
# TRAIN[17714] == TEST[34]
# TRAIN[26] == TEST[100]
# TRAIN[293] == TEST[100]
# TRAIN[445] == TEST[100]
# TRAIN[468] == TEST[100]
# TRAIN[543] == TEST[100]
# TRAIN[951] == TEST[100]
# TRAIN[1013] == TEST[100]
# TRAIN[1212] == TEST[100]
# TRAIN[1288] == TEST[100]
# TRAIN[1535] == TEST[100]
# TRAIN[1560] == TEST[100]
# TRAIN[1599] == TEST[100]
# TRAIN[1600] == TEST[100]
# TRAIN[1700] == TEST[100]
# TRAIN[1810] == TEST[100]
# TRAIN[1933] == TEST[100]
# TRAIN[1988] == TEST[100]
# TRAIN[1992] == TEST[100]
# TRAIN[2039] == TEST[100]
# TRAIN[2046] == TEST[100]
# TRAIN[2066] == TEST[100]
# TRAIN[2275] == TEST[100]
# TRAIN[2333] == TEST[100]
# TRAIN[2396] == TEST[100]
# TRAIN[2486] == TEST[100]
# TRAIN[2603] == TEST[100]
# TRAIN[2625] == TEST[100]
# TRAIN[2656] == TEST[100]
# TRAIN[2843] == TEST[100]
# TRAIN[2880] == TEST[100]
# TRAIN[2959] == TEST[100]
# TRAIN[3040] == TEST[100]
# TRAIN[3217] == TEST[100]
# TRAIN[3268] == TEST[100]
# TRAIN[3475] == TEST[100]
# TRAIN[3477] == TEST[100]
# TRAIN[3494] == TEST[100]
# TRAIN[3616] == TEST[100]
# TRAIN[3660] == TEST[100]
# TRAIN[3709] == TEST[100]
# TRAIN[3749] == TEST[100]
# TRAIN[3810] == TEST[100]
# TRAIN[3907] == TEST[100]
# TRAIN[3994] == TEST[100]
# TRAIN[4045] == TEST[100]
# TRAIN[4046] == TEST[100]
# TRAIN[4226] == TEST[100]
# TRAIN[4287] == TEST[100]
# TRAIN[4437] == TEST[100]
# TRAIN[4449] == TEST[100]
# TRAIN[4563] == TEST[100]
# TRAIN[4836] == TEST[100]
# TRAIN[4942] == TEST[100]
# TRAIN[4989] == TEST[100]
# TRAIN[5032] == TEST[100]
# TRAIN[5147] == TEST[100]
# TRAIN[5297] == TEST[100]
# TRAIN[5477] == TEST[100]
# TRAIN[5496] == TEST[100]
# TRAIN[5500] == TEST[100]
# TRAIN[5509] == TEST[100]
# TRAIN[5511] == TEST[100]
# TRAIN[5524] == TEST[100]
# TRAIN[5542] == TEST[100]
# TRAIN[5645] == TEST[100]
# TRAIN[5653] == TEST[100]
# TRAIN[5654] == TEST[100]
# TRAIN[5795] == TEST[100]
# TRAIN[6083] == TEST[100]
# TRAIN[6092] == TEST[100]
# TRAIN[6123] == TEST[100]
# TRAIN[6139] == TEST[100]
# TRAIN[6458] == TEST[100]
# TRAIN[6475] == TEST[100]
# TRAIN[6784] == TEST[100]
# TRAIN[7092] == TEST[100]
# TRAIN[7119] == TEST[100]
# TRAIN[7244] == TEST[100]
# TRAIN[7255] == TEST[100]
# TRAIN[7273] == TEST[100]
# TRAIN[7514] == TEST[100]
# TRAIN[7686] == TEST[100]
# TRAIN[8012] == TEST[100]
# TRAIN[8023] == TEST[100]
# TRAIN[8085] == TEST[100]
# TRAIN[8131] == TEST[100]
# TRAIN[8145] == TEST[100]
# TRAIN[8148] == TEST[100]
# TRAIN[8165] == TEST[100]
# TRAIN[8240] == TEST[100]
# TRAIN[8290] == TEST[100]
# TRAIN[8332] == TEST[100]
# TRAIN[8520] == TEST[100]
# TRAIN[8713] == TEST[100]
# TRAIN[8813] == TEST[100]
# TRAIN[8815] == TEST[100]
# TRAIN[8931] == TEST[100]
# TRAIN[9013] == TEST[100]
# TRAIN[9204] == TEST[100]
# TRAIN[9278] == TEST[100]
# TRAIN[9341] == TEST[100]
# TRAIN[9362] == TEST[100]
# TRAIN[9414] == TEST[100]
# TRAIN[9606] == TEST[100]
# TRAIN[9640] == TEST[100]
# TRAIN[9786] == TEST[100]
# TRAIN[9816] == TEST[100]
# TRAIN[9869] == TEST[100]
# TRAIN[9960] == TEST[100]
# TRAIN[10136] == TEST[100]
# TRAIN[10167] == TEST[100]
# TRAIN[10342] == TEST[100]
# TRAIN[10380] == TEST[100]
# TRAIN[10426] == TEST[100]
# TRAIN[10448] == TEST[100]
# TRAIN[10510] == TEST[100]
# TRAIN[10547] == TEST[100]
# TRAIN[10665] == TEST[100]
# TRAIN[10681] == TEST[100]
# TRAIN[10716] == TEST[100]
# TRAIN[10722] == TEST[100]
# TRAIN[10994] == TEST[100]
# TRAIN[10996] == TEST[100]
# TRAIN[11150] == TEST[100]
# TRAIN[11232] == TEST[100]
# TRAIN[11354] == TEST[100]
# TRAIN[11460] == TEST[100]
# TRAIN[11575] == TEST[100]
# TRAIN[11727] == TEST[100]
# TRAIN[11898] == TEST[100]
# TRAIN[12362] == TEST[100]
# TRAIN[12451] == TEST[100]
# TRAIN[12669] == TEST[100]
# TRAIN[12738] == TEST[100]
# TRAIN[12954] == TEST[100]
# TRAIN[12984] == TEST[100]
# TRAIN[12986] == TEST[100]
# TRAIN[13230] == TEST[100]
# TRAIN[13430] == TEST[100]
# TRAIN[13523] == TEST[100]
# TRAIN[13592] == TEST[100]
# TRAIN[13777] == TEST[100]
# TRAIN[13789] == TEST[100]
# TRAIN[13855] == TEST[100]
# TRAIN[13995] == TEST[100]
# TRAIN[14054] == TEST[100]
# TRAIN[14111] == TEST[100]
# TRAIN[14168] == TEST[100]
# TRAIN[14274] == TEST[100]
# TRAIN[14415] == TEST[100]
# TRAIN[14768] == TEST[100]
# TRAIN[14777] == TEST[100]
# TRAIN[15372] == TEST[100]
# TRAIN[15394] == TEST[100]
# TRAIN[15450] == TEST[100]
# TRAIN[15466] == TEST[100]
# TRAIN[15481] == TEST[100]
# TRAIN[15578] == TEST[100]
# TRAIN[15638] == TEST[100]
# TRAIN[15746] == TEST[100]
# TRAIN[15914] == TEST[100]
# TRAIN[15958] == TEST[100]
# TRAIN[15983] == TEST[100]
# TRAIN[16138] == TEST[100]
# TRAIN[16265] == TEST[100]
# TRAIN[16294] == TEST[100]
# TRAIN[16448] == TEST[100]
# TRAIN[16508] == TEST[100]
# TRAIN[16690] == TEST[100]
# TRAIN[16731] == TEST[100]
# TRAIN[16886] == TEST[100]
# TRAIN[17067] == TEST[100]
# TRAIN[17159] == TEST[100]
# TRAIN[17182] == TEST[100]
# TRAIN[17191] == TEST[100]
# TRAIN[17222] == TEST[100]
# TRAIN[17295] == TEST[100]
# TRAIN[17673] == TEST[100]
# TRAIN[17725] == TEST[100]
# TRAIN[17737] == TEST[100]
# TRAIN[17828] == TEST[100]
# TRAIN[17874] == TEST[100]
# TRAIN[18185] == TEST[100]
# TRAIN[18208] == TEST[100]
# TRAIN[18294] == TEST[100]
# TRAIN[18327] == TEST[100]
# TRAIN[18493] == TEST[100]
# TRAIN[18511] == TEST[100]
# TRAIN[18541] == TEST[100]
# TRAIN[18629] == TEST[100]
# TRAIN[18983] == TEST[100]
# TRAIN[19086] == TEST[100]
# TRAIN[19160] == TEST[100]
# TRAIN[19263] == TEST[100]
# TRAIN[19286] == TEST[100]
# TRAIN[19308] == TEST[100]
# TRAIN[19465] == TEST[100]
# TRAIN[19584] == TEST[100]
# TRAIN[19609] == TEST[100]
# TRAIN[19690] == TEST[100]
# TRAIN[19848] == TEST[100]
# TRAIN[13838] == TEST[111]
# TRAIN[9066] == TEST[135]
# TRAIN[12757] == TEST[217]
# TRAIN[26] == TEST[247]
# TRAIN[293] == TEST[247]
# TRAIN[445] == TEST[247]
# TRAIN[468] == TEST[247]
# TRAIN[543] == TEST[247]
# TRAIN[951] == TEST[247]
# TRAIN[1013] == TEST[247]
# TRAIN[1212] == TEST[247]
# TRAIN[1288] == TEST[247]
# TRAIN[1535] == TEST[247]
# TRAIN[1560] == TEST[247]
# TRAIN[1599] == TEST[247]
# TRAIN[1600] == TEST[247]
# TRAIN[1700] == TEST[247]
# TRAIN[1810] == TEST[247]
# TRAIN[1933] == TEST[247]
# TRAIN[1988] == TEST[247]
# TRAIN[1992] == TEST[247]
# TRAIN[2039] == TEST[247]
# TRAIN[2046] == TEST[247]
# TRAIN[2066] == TEST[247]
# TRAIN[2275] == TEST[247]
# TRAIN[2333] == TEST[247]
# TRAIN[2396] == TEST[247]
# TRAIN[2486] == TEST[247]
# TRAIN[2603] == TEST[247]
# TRAIN[2625] == TEST[247]
# TRAIN[2656] == TEST[247]
# TRAIN[2843] == TEST[247]
# TRAIN[2880] == TEST[247]
# TRAIN[2959] == TEST[247]
# TRAIN[3040] == TEST[247]
# TRAIN[3217] == TEST[247]
# TRAIN[3268] == TEST[247]
# TRAIN[3475] == TEST[247]
# TRAIN[3477] == TEST[247]
# TRAIN[3494] == TEST[247]
# TRAIN[3616] == TEST[247]
# TRAIN[3660] == TEST[247]
# TRAIN[3709] == TEST[247]
# TRAIN[3749] == TEST[247]
# TRAIN[3810] == TEST[247]
# TRAIN[3907] == TEST[247]
# TRAIN[3994] == TEST[247]
# TRAIN[4045] == TEST[247]
# TRAIN[4046] == TEST[247]
# TRAIN[4226] == TEST[247]
# TRAIN[4287] == TEST[247]
# TRAIN[4437] == TEST[247]
# TRAIN[4449] == TEST[247]
# TRAIN[4563] == TEST[247]
# TRAIN[4836] == TEST[247]
# TRAIN[4942] == TEST[247]
# TRAIN[4989] == TEST[247]
# TRAIN[5032] == TEST[247]
# TRAIN[5147] == TEST[247]
# TRAIN[5297] == TEST[247]
# TRAIN[5477] == TEST[247]
# TRAIN[5496] == TEST[247]
# TRAIN[5500] == TEST[247]
# TRAIN[5509] == TEST[247]
# TRAIN[5511] == TEST[247]
# TRAIN[5524] == TEST[247]
# TRAIN[5542] == TEST[247]
# TRAIN[5645] == TEST[247]
# TRAIN[5653] == TEST[247]
# TRAIN[5654] == TEST[247]
# TRAIN[5795] == TEST[247]
# TRAIN[6083] == TEST[247]
# TRAIN[6092] == TEST[247]
# TRAIN[6123] == TEST[247]
# TRAIN[6139] == TEST[247]
# TRAIN[6458] == TEST[247]
# TRAIN[6475] == TEST[247]
# TRAIN[6784] == TEST[247]
# TRAIN[7092] == TEST[247]
# TRAIN[7119] == TEST[247]
# TRAIN[7244] == TEST[247]
# TRAIN[7255] == TEST[247]
# TRAIN[7273] == TEST[247]
# TRAIN[7514] == TEST[247]
# TRAIN[7686] == TEST[247]
# TRAIN[8012] == TEST[247]
# TRAIN[8023] == TEST[247]
# TRAIN[8085] == TEST[247]
# TRAIN[8131] == TEST[247]
# TRAIN[8145] == TEST[247]
# TRAIN[8148] == TEST[247]
# TRAIN[8165] == TEST[247]
# TRAIN[8240] == TEST[247]
# TRAIN[8290] == TEST[247]
# TRAIN[8332] == TEST[247]
# TRAIN[8520] == TEST[247]
# TRAIN[8713] == TEST[247]
# TRAIN[8813] == TEST[247]
# TRAIN[8815] == TEST[247]
# TRAIN[8931] == TEST[247]
# TRAIN[9013] == TEST[247]
# TRAIN[9204] == TEST[247]
# TRAIN[9278] == TEST[247]
# TRAIN[9341] == TEST[247]
# TRAIN[9362] == TEST[247]
# TRAIN[9414] == TEST[247]
# TRAIN[9606] == TEST[247]
# TRAIN[9640] == TEST[247]
# TRAIN[9786] == TEST[247]
# TRAIN[9816] == TEST[247]
# TRAIN[9869] == TEST[247]
# TRAIN[9960] == TEST[247]
# TRAIN[10136] == TEST[247]
# TRAIN[10167] == TEST[247]
# TRAIN[10342] == TEST[247]
# TRAIN[10380] == TEST[247]
# TRAIN[10426] == TEST[247]
# TRAIN[10448] == TEST[247]
# TRAIN[10510] == TEST[247]
# TRAIN[10547] == TEST[247]
# TRAIN[10665] == TEST[247]
# TRAIN[10681] == TEST[247]
# TRAIN[10716] == TEST[247]
# TRAIN[10722] == TEST[247]
# TRAIN[10994] == TEST[247]
# TRAIN[10996] == TEST[247]
# TRAIN[11150] == TEST[247]
# TRAIN[11232] == TEST[247]
# TRAIN[11354] == TEST[247]
# TRAIN[11460] == TEST[247]
# TRAIN[11575] == TEST[247]
# TRAIN[11727] == TEST[247]
# TRAIN[11898] == TEST[247]
# TRAIN[12362] == TEST[247]
# TRAIN[12451] == TEST[247]
# TRAIN[12669] == TEST[247]
# TRAIN[12738] == TEST[247]
# TRAIN[12954] == TEST[247]
# TRAIN[12984] == TEST[247]
# TRAIN[12986] == TEST[247]
# TRAIN[13230] == TEST[247]
# TRAIN[13430] == TEST[247]
# TRAIN[13523] == TEST[247]
# TRAIN[13592] == TEST[247]
# TRAIN[13777] == TEST[247]
# TRAIN[13789] == TEST[247]
# TRAIN[13855] == TEST[247]
# TRAIN[13995] == TEST[247]
# TRAIN[14054] == TEST[247]
# TRAIN[14111] == TEST[247]
# TRAIN[14168] == TEST[247]
# TRAIN[14274] == TEST[247]
# TRAIN[14415] == TEST[247]
# TRAIN[14768] == TEST[247]
# TRAIN[14777] == TEST[247]
# TRAIN[15372] == TEST[247]
# TRAIN[15394] == TEST[247]
# TRAIN[15450] == TEST[247]
# TRAIN[15466] == TEST[247]
# TRAIN[15481] == TEST[247]
# TRAIN[15578] == TEST[247]
# TRAIN[15638] == TEST[247]
# TRAIN[15746] == TEST[247]
# TRAIN[15914] == TEST[247]
# TRAIN[15958] == TEST[247]
# TRAIN[15983] == TEST[247]
# TRAIN[16138] == TEST[247]
# TRAIN[16265] == TEST[247]
# TRAIN[16294] == TEST[247]
# TRAIN[16448] == TEST[247]
# TRAIN[16508] == TEST[247]
# TRAIN[16690] == TEST[247]
# TRAIN[16731] == TEST[247]
# TRAIN[16886] == TEST[247]
# TRAIN[17067] == TEST[247]
# TRAIN[17159] == TEST[247]
# TRAIN[17182] == TEST[247]
# TRAIN[17191] == TEST[247]
# TRAIN[17222] == TEST[247]
# TRAIN[17295] == TEST[247]
# TRAIN[17673] == TEST[247]
# TRAIN[17725] == TEST[247]
# TRAIN[17737] == TEST[247]
# TRAIN[17828] == TEST[247]
# TRAIN[17874] == TEST[247]
# TRAIN[18185] == TEST[247]
# TRAIN[18208] == TEST[247]
# TRAIN[18294] == TEST[247]
# TRAIN[18327] == TEST[247]
# TRAIN[18493] == TEST[247]
# TRAIN[18511] == TEST[247]
# TRAIN[18541] == TEST[247]
# TRAIN[18629] == TEST[247]
# TRAIN[18983] == TEST[247]
# TRAIN[19086] == TEST[247]
# TRAIN[19160] == TEST[247]
# TRAIN[19263] == TEST[247]
# TRAIN[19286] == TEST[247]
# TRAIN[19308] == TEST[247]
# TRAIN[19465] == TEST[247]
# TRAIN[19584] == TEST[247]
# TRAIN[19609] == TEST[247]
# TRAIN[19690] == TEST[247]
# TRAIN[19848] == TEST[247]
# TRAIN[4454] == TEST[295]
# TRAIN[26] == TEST[318]
# TRAIN[293] == TEST[318]
# TRAIN[445] == TEST[318]
# TRAIN[468] == TEST[318]
# TRAIN[543] == TEST[318]
# TRAIN[951] == TEST[318]
# TRAIN[1013] == TEST[318]
# TRAIN[1212] == TEST[318]
# TRAIN[1288] == TEST[318]
# TRAIN[1535] == TEST[318]
# TRAIN[1560] == TEST[318]
# TRAIN[1599] == TEST[318]
# TRAIN[1600] == TEST[318]
# TRAIN[1700] == TEST[318]
# TRAIN[1810] == TEST[318]
# TRAIN[1933] == TEST[318]
# TRAIN[1988] == TEST[318]
# TRAIN[1992] == TEST[318]
# TRAIN[2039] == TEST[318]
# TRAIN[2046] == TEST[318]
# TRAIN[2066] == TEST[318]
# TRAIN[2275] == TEST[318]
# TRAIN[2333] == TEST[318]
# TRAIN[2396] == TEST[318]
# TRAIN[2486] == TEST[318]
# TRAIN[2603] == TEST[318]
# TRAIN[2625] == TEST[318]
# TRAIN[2656] == TEST[318]
# TRAIN[2843] == TEST[318]
# TRAIN[2880] == TEST[318]
# TRAIN[2959] == TEST[318]
# TRAIN[3040] == TEST[318]
# TRAIN[3217] == TEST[318]
# TRAIN[3268] == TEST[318]
# TRAIN[3475] == TEST[318]
# TRAIN[3477] == TEST[318]
# TRAIN[3494] == TEST[318]
# TRAIN[3616] == TEST[318]
# TRAIN[3660] == TEST[318]
# TRAIN[3709] == TEST[318]
# TRAIN[3749] == TEST[318]
# TRAIN[3810] == TEST[318]
# TRAIN[3907] == TEST[318]
# TRAIN[3994] == TEST[318]
# TRAIN[4045] == TEST[318]
# TRAIN[4046] == TEST[318]
# TRAIN[4226] == TEST[318]
# TRAIN[4287] == TEST[318]
# TRAIN[4437] == TEST[318]
# TRAIN[4449] == TEST[318]
# TRAIN[4563] == TEST[318]
# TRAIN[4836] == TEST[318]
# TRAIN[4942] == TEST[318]
# TRAIN[4989] == TEST[318]
# TRAIN[5032] == TEST[318]
# TRAIN[5147] == TEST[318]
# TRAIN[5297] == TEST[318]
# TRAIN[5477] == TEST[318]
# TRAIN[5496] == TEST[318]
# TRAIN[5500] == TEST[318]
# TRAIN[5509] == TEST[318]
# TRAIN[5511] == TEST[318]
# TRAIN[5524] == TEST[318]
# TRAIN[5542] == TEST[318]
# TRAIN[5645] == TEST[318]
# TRAIN[5653] == TEST[318]
# TRAIN[5654] == TEST[318]
# TRAIN[5795] == TEST[318]
# TRAIN[6083] == TEST[318]
# TRAIN[6092] == TEST[318]
# TRAIN[6123] == TEST[318]
# TRAIN[6139] == TEST[318]
# TRAIN[6458] == TEST[318]
# TRAIN[6475] == TEST[318]
# TRAIN[6784] == TEST[318]
# TRAIN[7092] == TEST[318]
# TRAIN[7119] == TEST[318]
# TRAIN[7244] == TEST[318]
# TRAIN[7255] == TEST[318]
# TRAIN[7273] == TEST[318]
# TRAIN[7514] == TEST[318]
# TRAIN[7686] == TEST[318]
# TRAIN[8012] == TEST[318]
# TRAIN[8023] == TEST[318]
# TRAIN[8085] == TEST[318]
# TRAIN[8131] == TEST[318]
# TRAIN[8145] == TEST[318]
# TRAIN[8148] == TEST[318]
# TRAIN[8165] == TEST[318]
# TRAIN[8240] == TEST[318]
# TRAIN[8290] == TEST[318]
# TRAIN[8332] == TEST[318]
# TRAIN[8520] == TEST[318]
# TRAIN[8713] == TEST[318]
# TRAIN[8813] == TEST[318]
# TRAIN[8815] == TEST[318]
# TRAIN[8931] == TEST[318]
# TRAIN[9013] == TEST[318]
# TRAIN[9204] == TEST[318]
# TRAIN[9278] == TEST[318]
# TRAIN[9341] == TEST[318]
# TRAIN[9362] == TEST[318]
# TRAIN[9414] == TEST[318]
# TRAIN[9606] == TEST[318]
# TRAIN[9640] == TEST[318]
# TRAIN[9786] == TEST[318]
# TRAIN[9816] == TEST[318]
# TRAIN[9869] == TEST[318]
# TRAIN[9960] == TEST[318]
# TRAIN[10136] == TEST[318]
# TRAIN[10167] == TEST[318]
# TRAIN[10342] == TEST[318]
# TRAIN[10380] == TEST[318]
# TRAIN[10426] == TEST[318]
# TRAIN[10448] == TEST[318]
# TRAIN[10510] == TEST[318]
# TRAIN[10547] == TEST[318]
# TRAIN[10665] == TEST[318]
# TRAIN[10681] == TEST[318]
# TRAIN[10716] == TEST[318]
# TRAIN[10722] == TEST[318]
# TRAIN[10994] == TEST[318]
# TRAIN[10996] == TEST[318]
# TRAIN[11150] == TEST[318]
# TRAIN[11232] == TEST[318]
# TRAIN[11354] == TEST[318]
# TRAIN[11460] == TEST[318]
# TRAIN[11575] == TEST[318]
# TRAIN[11727] == TEST[318]
# TRAIN[11898] == TEST[318]
# TRAIN[12362] == TEST[318]
# TRAIN[12451] == TEST[318]
# TRAIN[12669] == TEST[318]
# TRAIN[12738] == TEST[318]
# TRAIN[12954] == TEST[318]
# TRAIN[12984] == TEST[318]
# TRAIN[12986] == TEST[318]
# TRAIN[13230] == TEST[318]
# TRAIN[13430] == TEST[318]
# TRAIN[13523] == TEST[318]
# TRAIN[13592] == TEST[318]
# TRAIN[13777] == TEST[318]
# TRAIN[13789] == TEST[318]
# TRAIN[13855] == TEST[318]
# TRAIN[13995] == TEST[318]
# TRAIN[14054] == TEST[318]
# TRAIN[14111] == TEST[318]
# TRAIN[14168] == TEST[318]
# TRAIN[14274] == TEST[318]
# TRAIN[14415] == TEST[318]
# TRAIN[14768] == TEST[318]
# TRAIN[14777] == TEST[318]
# TRAIN[15372] == TEST[318]
# TRAIN[15394] == TEST[318]
# TRAIN[15450] == TEST[318]
# TRAIN[15466] == TEST[318]
# TRAIN[15481] == TEST[318]
# TRAIN[15578] == TEST[318]
# TRAIN[15638] == TEST[318]
# TRAIN[15746] == TEST[318]
# TRAIN[15914] == TEST[318]
# TRAIN[15958] == TEST[318]
# TRAIN[15983] == TEST[318]
# TRAIN[16138] == TEST[318]
# TRAIN[16265] == TEST[318]
# TRAIN[16294] == TEST[318]
# TRAIN[16448] == TEST[318]
# TRAIN[16508] == TEST[318]
# TRAIN[16690] == TEST[318]
# TRAIN[16731] == TEST[318]
# TRAIN[16886] == TEST[318]
# TRAIN[17067] == TEST[318]
# TRAIN[17159] == TEST[318]
# TRAIN[17182] == TEST[318]
# TRAIN[17191] == TEST[318]
# TRAIN[17222] == TEST[318]
# TRAIN[17295] == TEST[318]
# TRAIN[17673] == TEST[318]
# TRAIN[17725] == TEST[318]
# TRAIN[17737] == TEST[318]
# TRAIN[17828] == TEST[318]
# TRAIN[17874] == TEST[318]
# TRAIN[18185] == TEST[318]
# TRAIN[18208] == TEST[318]
# TRAIN[18294] == TEST[318]
# TRAIN[18327] == TEST[318]
# TRAIN[18493] == TEST[318]
# TRAIN[18511] == TEST[318]
# TRAIN[18541] == TEST[318]
# TRAIN[18629] == TEST[318]
# TRAIN[18983] == TEST[318]
# TRAIN[19086] == TEST[318]
# TRAIN[19160] == TEST[318]
# TRAIN[19263] == TEST[318]
# TRAIN[19286] == TEST[318]
# TRAIN[19308] == TEST[318]
# TRAIN[19465] == TEST[318]
# TRAIN[19584] == TEST[318]
# TRAIN[19609] == TEST[318]
# TRAIN[19690] == TEST[318]
# TRAIN[19848] == TEST[318]
# TRAIN[26] == TEST[337]
# TRAIN[293] == TEST[337]
# TRAIN[445] == TEST[337]
# TRAIN[468] == TEST[337]
# TRAIN[543] == TEST[337]
# TRAIN[951] == TEST[337]
# TRAIN[1013] == TEST[337]
# TRAIN[1212] == TEST[337]
# TRAIN[1288] == TEST[337]
# TRAIN[1535] == TEST[337]
# TRAIN[1560] == TEST[337]
# TRAIN[1599] == TEST[337]
# TRAIN[1600] == TEST[337]
# TRAIN[1700] == TEST[337]
# TRAIN[1810] == TEST[337]
# TRAIN[1933] == TEST[337]
# TRAIN[1988] == TEST[337]
# TRAIN[1992] == TEST[337]
# TRAIN[2039] == TEST[337]
# TRAIN[2046] == TEST[337]
# TRAIN[2066] == TEST[337]
# TRAIN[2275] == TEST[337]
# TRAIN[2333] == TEST[337]
# TRAIN[2396] == TEST[337]
# TRAIN[2486] == TEST[337]
# TRAIN[2603] == TEST[337]
# TRAIN[2625] == TEST[337]
# TRAIN[2656] == TEST[337]
# TRAIN[2843] == TEST[337]
# TRAIN[2880] == TEST[337]
# TRAIN[2959] == TEST[337]
# TRAIN[3040] == TEST[337]
# TRAIN[3217] == TEST[337]
# TRAIN[3268] == TEST[337]
# TRAIN[3475] == TEST[337]
# TRAIN[3477] == TEST[337]
# TRAIN[3494] == TEST[337]
# TRAIN[3616] == TEST[337]
# TRAIN[3660] == TEST[337]
# TRAIN[3709] == TEST[337]
# TRAIN[3749] == TEST[337]
# TRAIN[3810] == TEST[337]
# TRAIN[3907] == TEST[337]
# TRAIN[3994] == TEST[337]
# TRAIN[4045] == TEST[337]
# TRAIN[4046] == TEST[337]
# TRAIN[4226] == TEST[337]
# TRAIN[4287] == TEST[337]
# TRAIN[4437] == TEST[337]
# TRAIN[4449] == TEST[337]
# TRAIN[4563] == TEST[337]
# TRAIN[4836] == TEST[337]
# TRAIN[4942] == TEST[337]
# TRAIN[4989] == TEST[337]
# TRAIN[5032] == TEST[337]
# TRAIN[5147] == TEST[337]
# TRAIN[5297] == TEST[337]
# TRAIN[5477] == TEST[337]
# TRAIN[5496] == TEST[337]
# TRAIN[5500] == TEST[337]
# TRAIN[5509] == TEST[337]
# TRAIN[5511] == TEST[337]
# TRAIN[5524] == TEST[337]
# TRAIN[5542] == TEST[337]
# TRAIN[5645] == TEST[337]
# TRAIN[5653] == TEST[337]
# TRAIN[5654] == TEST[337]
# TRAIN[5795] == TEST[337]
# TRAIN[6083] == TEST[337]
# TRAIN[6092] == TEST[337]
# TRAIN[6123] == TEST[337]
# TRAIN[6139] == TEST[337]
# TRAIN[6458] == TEST[337]
# TRAIN[6475] == TEST[337]
# TRAIN[6784] == TEST[337]
# TRAIN[7092] == TEST[337]
# TRAIN[7119] == TEST[337]
# TRAIN[7244] == TEST[337]
# TRAIN[7255] == TEST[337]
# TRAIN[7273] == TEST[337]
# TRAIN[7514] == TEST[337]
# TRAIN[7686] == TEST[337]
# TRAIN[8012] == TEST[337]
# TRAIN[8023] == TEST[337]
# TRAIN[8085] == TEST[337]
# TRAIN[8131] == TEST[337]
# TRAIN[8145] == TEST[337]
# TRAIN[8148] == TEST[337]
# TRAIN[8165] == TEST[337]
# TRAIN[8240] == TEST[337]
# TRAIN[8290] == TEST[337]
# TRAIN[8332] == TEST[337]
# TRAIN[8520] == TEST[337]
# TRAIN[8713] == TEST[337]
# TRAIN[8813] == TEST[337]
# TRAIN[8815] == TEST[337]
# TRAIN[8931] == TEST[337]
# TRAIN[9013] == TEST[337]
# TRAIN[9204] == TEST[337]
# TRAIN[9278] == TEST[337]
# TRAIN[9341] == TEST[337]
# TRAIN[9362] == TEST[337]
# TRAIN[9414] == TEST[337]
# TRAIN[9606] == TEST[337]
# TRAIN[9640] == TEST[337]
# TRAIN[9786] == TEST[337]
# TRAIN[9816] == TEST[337]
# TRAIN[9869] == TEST[337]
# TRAIN[9960] == TEST[337]
# TRAIN[10136] == TEST[337]
# TRAIN[10167] == TEST[337]
# TRAIN[10342] == TEST[337]
# TRAIN[10380] == TEST[337]
# TRAIN[10426] == TEST[337]
# TRAIN[10448] == TEST[337]
# TRAIN[10510] == TEST[337]
# TRAIN[10547] == TEST[337]
# TRAIN[10665] == TEST[337]
# TRAIN[10681] == TEST[337]
# TRAIN[10716] == TEST[337]
# TRAIN[10722] == TEST[337]
# TRAIN[10994] == TEST[337]
# TRAIN[10996] == TEST[337]
# TRAIN[11150] == TEST[337]
# TRAIN[11232] == TEST[337]
# TRAIN[11354] == TEST[337]
# TRAIN[11460] == TEST[337]
# TRAIN[11575] == TEST[337]
# TRAIN[11727] == TEST[337]
# TRAIN[11898] == TEST[337]
# TRAIN[12362] == TEST[337]
# TRAIN[12451] == TEST[337]
# TRAIN[12669] == TEST[337]
# TRAIN[12738] == TEST[337]
# TRAIN[12954] == TEST[337]
# TRAIN[12984] == TEST[337]
# TRAIN[12986] == TEST[337]
# TRAIN[13230] == TEST[337]
# TRAIN[13430] == TEST[337]
# TRAIN[13523] == TEST[337]
# TRAIN[13592] == TEST[337]
# TRAIN[13777] == TEST[337]
# TRAIN[13789] == TEST[337]
# TRAIN[13855] == TEST[337]
# TRAIN[13995] == TEST[337]
# TRAIN[14054] == TEST[337]
# TRAIN[14111] == TEST[337]
# TRAIN[14168] == TEST[337]
# TRAIN[14274] == TEST[337]
# TRAIN[14415] == TEST[337]
# TRAIN[14768] == TEST[337]
# TRAIN[14777] == TEST[337]
# TRAIN[15372] == TEST[337]
# TRAIN[15394] == TEST[337]
# TRAIN[15450] == TEST[337]
# TRAIN[15466] == TEST[337]
# TRAIN[15481] == TEST[337]
# TRAIN[15578] == TEST[337]
# TRAIN[15638] == TEST[337]
# TRAIN[15746] == TEST[337]
# TRAIN[15914] == TEST[337]
# TRAIN[15958] == TEST[337]
# TRAIN[15983] == TEST[337]
# TRAIN[16138] == TEST[337]
# TRAIN[16265] == TEST[337]
# TRAIN[16294] == TEST[337]
# TRAIN[16448] == TEST[337]
# TRAIN[16508] == TEST[337]
# TRAIN[16690] == TEST[337]
# TRAIN[16731] == TEST[337]
# TRAIN[16886] == TEST[337]
# TRAIN[17067] == TEST[337]
# TRAIN[17159] == TEST[337]
# TRAIN[17182] == TEST[337]
# TRAIN[17191] == TEST[337]
# TRAIN[17222] == TEST[337]
# TRAIN[17295] == TEST[337]
# TRAIN[17673] == TEST[337]
# TRAIN[17725] == TEST[337]
# TRAIN[17737] == TEST[337]
# TRAIN[17828] == TEST[337]
# TRAIN[17874] == TEST[337]
# TRAIN[18185] == TEST[337]
# TRAIN[18208] == TEST[337]
# TRAIN[18294] == TEST[337]
# TRAIN[18327] == TEST[337]
# TRAIN[18493] == TEST[337]
# TRAIN[18511] == TEST[337]
# TRAIN[18541] == TEST[337]
# TRAIN[18629] == TEST[337]
# TRAIN[18983] == TEST[337]
# TRAIN[19086] == TEST[337]
# TRAIN[19160] == TEST[337]
# TRAIN[19263] == TEST[337]
# TRAIN[19286] == TEST[337]
# TRAIN[19308] == TEST[337]
# TRAIN[19465] == TEST[337]
# TRAIN[19584] == TEST[337]
# TRAIN[19609] == TEST[337]
# TRAIN[19690] == TEST[337]
# TRAIN[19848] == TEST[337]
# TRAIN[26] == TEST[407]
# TRAIN[293] == TEST[407]
# TRAIN[445] == TEST[407]
# TRAIN[468] == TEST[407]
# TRAIN[543] == TEST[407]
# TRAIN[951] == TEST[407]
# TRAIN[1013] == TEST[407]
# TRAIN[1212] == TEST[407]
# TRAIN[1288] == TEST[407]
# TRAIN[1535] == TEST[407]
# TRAIN[1560] == TEST[407]
# TRAIN[1599] == TEST[407]
# TRAIN[1600] == TEST[407]
# TRAIN[1700] == TEST[407]
# TRAIN[1810] == TEST[407]
# TRAIN[1933] == TEST[407]
# TRAIN[1988] == TEST[407]
# TRAIN[1992] == TEST[407]
# TRAIN[2039] == TEST[407]
# TRAIN[2046] == TEST[407]
# TRAIN[2066] == TEST[407]
# TRAIN[2275] == TEST[407]
# TRAIN[2333] == TEST[407]
# TRAIN[2396] == TEST[407]
# TRAIN[2486] == TEST[407]
# TRAIN[2603] == TEST[407]
# TRAIN[2625] == TEST[407]
# TRAIN[2656] == TEST[407]
# TRAIN[2843] == TEST[407]
# TRAIN[2880] == TEST[407]
# TRAIN[2959] == TEST[407]
# TRAIN[3040] == TEST[407]
# TRAIN[3217] == TEST[407]
# TRAIN[3268] == TEST[407]
# TRAIN[3475] == TEST[407]
# TRAIN[3477] == TEST[407]
# TRAIN[3494] == TEST[407]
# TRAIN[3616] == TEST[407]
# TRAIN[3660] == TEST[407]
# TRAIN[3709] == TEST[407]
# TRAIN[3749] == TEST[407]
# TRAIN[3810] == TEST[407]
# TRAIN[3907] == TEST[407]
# TRAIN[3994] == TEST[407]
# TRAIN[4045] == TEST[407]
# TRAIN[4046] == TEST[407]
# TRAIN[4226] == TEST[407]
# TRAIN[4287] == TEST[407]
# TRAIN[4437] == TEST[407]
# TRAIN[4449] == TEST[407]
# TRAIN[4563] == TEST[407]
# TRAIN[4836] == TEST[407]
# TRAIN[4942] == TEST[407]
# TRAIN[4989] == TEST[407]
# TRAIN[5032] == TEST[407]
# TRAIN[5147] == TEST[407]
# TRAIN[5297] == TEST[407]
# TRAIN[5477] == TEST[407]
# TRAIN[5496] == TEST[407]
# TRAIN[5500] == TEST[407]
# TRAIN[5509] == TEST[407]
# TRAIN[5511] == TEST[407]
# TRAIN[5524] == TEST[407]
# TRAIN[5542] == TEST[407]
# TRAIN[5645] == TEST[407]
# TRAIN[5653] == TEST[407]
# TRAIN[5654] == TEST[407]
# TRAIN[5795] == TEST[407]
# TRAIN[6083] == TEST[407]
# TRAIN[6092] == TEST[407]
# TRAIN[6123] == TEST[407]
# TRAIN[6139] == TEST[407]
# TRAIN[6458] == TEST[407]
# TRAIN[6475] == TEST[407]
# TRAIN[6784] == TEST[407]
# TRAIN[7092] == TEST[407]
# TRAIN[7119] == TEST[407]
# TRAIN[7244] == TEST[407]
# TRAIN[7255] == TEST[407]
# TRAIN[7273] == TEST[407]
# TRAIN[7514] == TEST[407]
# TRAIN[7686] == TEST[407]
# TRAIN[8012] == TEST[407]
# TRAIN[8023] == TEST[407]
# TRAIN[8085] == TEST[407]
# TRAIN[8131] == TEST[407]
# TRAIN[8145] == TEST[407]
# TRAIN[8148] == TEST[407]
# TRAIN[8165] == TEST[407]
# TRAIN[8240] == TEST[407]
# TRAIN[8290] == TEST[407]
# TRAIN[8332] == TEST[407]
# TRAIN[8520] == TEST[407]
# TRAIN[8713] == TEST[407]
# TRAIN[8813] == TEST[407]
# TRAIN[8815] == TEST[407]
# TRAIN[8931] == TEST[407]
# TRAIN[9013] == TEST[407]
# TRAIN[9204] == TEST[407]
# TRAIN[9278] == TEST[407]
# TRAIN[9341] == TEST[407]
# TRAIN[9362] == TEST[407]
# TRAIN[9414] == TEST[407]
# TRAIN[9606] == TEST[407]
# TRAIN[9640] == TEST[407]
# TRAIN[9786] == TEST[407]
# TRAIN[9816] == TEST[407]
# TRAIN[9869] == TEST[407]
# TRAIN[9960] == TEST[407]
# TRAIN[10136] == TEST[407]
# TRAIN[10167] == TEST[407]
# TRAIN[10342] == TEST[407]
# TRAIN[10380] == TEST[407]
# TRAIN[10426] == TEST[407]
# TRAIN[10448] == TEST[407]
# TRAIN[10510] == TEST[407]
# TRAIN[10547] == TEST[407]
# TRAIN[10665] == TEST[407]
# TRAIN[10681] == TEST[407]
# TRAIN[10716] == TEST[407]
# TRAIN[10722] == TEST[407]
# TRAIN[10994] == TEST[407]
# TRAIN[10996] == TEST[407]
# TRAIN[11150] == TEST[407]
# TRAIN[11232] == TEST[407]
# TRAIN[11354] == TEST[407]
# TRAIN[11460] == TEST[407]
# TRAIN[11575] == TEST[407]
# TRAIN[11727] == TEST[407]
# TRAIN[11898] == TEST[407]
# TRAIN[12362] == TEST[407]
# TRAIN[12451] == TEST[407]
# TRAIN[12669] == TEST[407]
# TRAIN[12738] == TEST[407]
# TRAIN[12954] == TEST[407]
# TRAIN[12984] == TEST[407]
# TRAIN[12986] == TEST[407]
# TRAIN[13230] == TEST[407]
# TRAIN[13430] == TEST[407]
# TRAIN[13523] == TEST[407]
# TRAIN[13592] == TEST[407]
# TRAIN[13777] == TEST[407]
# TRAIN[13789] == TEST[407]
# TRAIN[13855] == TEST[407]
# TRAIN[13995] == TEST[407]
# TRAIN[14054] == TEST[407]
# TRAIN[14111] == TEST[407]
# TRAIN[14168] == TEST[407]
# TRAIN[14274] == TEST[407]
# TRAIN[14415] == TEST[407]
# TRAIN[14768] == TEST[407]
# TRAIN[14777] == TEST[407]
# TRAIN[15372] == TEST[407]
# TRAIN[15394] == TEST[407]
# TRAIN[15450] == TEST[407]
# TRAIN[15466] == TEST[407]
# TRAIN[15481] == TEST[407]
# TRAIN[15578] == TEST[407]
# TRAIN[15638] == TEST[407]
# TRAIN[15746] == TEST[407]
# TRAIN[15914] == TEST[407]
# TRAIN[15958] == TEST[407]
# TRAIN[15983] == TEST[407]
# TRAIN[16138] == TEST[407]
# TRAIN[16265] == TEST[407]
# TRAIN[16294] == TEST[407]
# TRAIN[16448] == TEST[407]
# TRAIN[16508] == TEST[407]
# TRAIN[16690] == TEST[407]
# TRAIN[16731] == TEST[407]
# TRAIN[16886] == TEST[407]
# TRAIN[17067] == TEST[407]
# TRAIN[17159] == TEST[407]
# TRAIN[17182] == TEST[407]
# TRAIN[17191] == TEST[407]
# TRAIN[17222] == TEST[407]
# TRAIN[17295] == TEST[407]
# TRAIN[17673] == TEST[407]
# TRAIN[17725] == TEST[407]
# TRAIN[17737] == TEST[407]
# TRAIN[17828] == TEST[407]
# TRAIN[17874] == TEST[407]
# TRAIN[18185] == TEST[407]
# TRAIN[18208] == TEST[407]
# TRAIN[18294] == TEST[407]
# TRAIN[18327] == TEST[407]
# TRAIN[18493] == TEST[407]
# TRAIN[18511] == TEST[407]
# TRAIN[18541] == TEST[407]
# TRAIN[18629] == TEST[407]
# TRAIN[18983] == TEST[407]
# TRAIN[19086] == TEST[407]
# TRAIN[19160] == TEST[407]
# TRAIN[19263] == TEST[407]
# TRAIN[19286] == TEST[407]
# TRAIN[19308] == TEST[407]
# TRAIN[19465] == TEST[407]
# TRAIN[19584] == TEST[407]
# TRAIN[19609] == TEST[407]
# TRAIN[19690] == TEST[407]
# TRAIN[19848] == TEST[407]
# TRAIN[26] == TEST[481]
# TRAIN[293] == TEST[481]
# TRAIN[445] == TEST[481]
# TRAIN[468] == TEST[481]
# TRAIN[543] == TEST[481]
# TRAIN[951] == TEST[481]
# TRAIN[1013] == TEST[481]
# TRAIN[1212] == TEST[481]
# TRAIN[1288] == TEST[481]
# TRAIN[1535] == TEST[481]
# TRAIN[1560] == TEST[481]
# TRAIN[1599] == TEST[481]
# TRAIN[1600] == TEST[481]
# TRAIN[1700] == TEST[481]
# TRAIN[1810] == TEST[481]
# TRAIN[1933] == TEST[481]
# TRAIN[1988] == TEST[481]
# TRAIN[1992] == TEST[481]
# TRAIN[2039] == TEST[481]
# TRAIN[2046] == TEST[481]
# TRAIN[2066] == TEST[481]
# TRAIN[2275] == TEST[481]
# TRAIN[2333] == TEST[481]
# TRAIN[2396] == TEST[481]
# TRAIN[2486] == TEST[481]
# TRAIN[2603] == TEST[481]
# TRAIN[2625] == TEST[481]
# TRAIN[2656] == TEST[481]
# TRAIN[2843] == TEST[481]
# TRAIN[2880] == TEST[481]
# TRAIN[2959] == TEST[481]
# TRAIN[3040] == TEST[481]
# TRAIN[3217] == TEST[481]
# TRAIN[3268] == TEST[481]
# TRAIN[3475] == TEST[481]
# TRAIN[3477] == TEST[481]
# TRAIN[3494] == TEST[481]
# TRAIN[3616] == TEST[481]
# TRAIN[3660] == TEST[481]
# TRAIN[3709] == TEST[481]
# TRAIN[3749] == TEST[481]
# TRAIN[3810] == TEST[481]
# TRAIN[3907] == TEST[481]
# TRAIN[3994] == TEST[481]
# TRAIN[4045] == TEST[481]
# TRAIN[4046] == TEST[481]
# TRAIN[4226] == TEST[481]
# TRAIN[4287] == TEST[481]
# TRAIN[4437] == TEST[481]
# TRAIN[4449] == TEST[481]
# TRAIN[4563] == TEST[481]
# TRAIN[4836] == TEST[481]
# TRAIN[4942] == TEST[481]
# TRAIN[4989] == TEST[481]
# TRAIN[5032] == TEST[481]
# TRAIN[5147] == TEST[481]
# TRAIN[5297] == TEST[481]
# TRAIN[5477] == TEST[481]
# TRAIN[5496] == TEST[481]
# TRAIN[5500] == TEST[481]
# TRAIN[5509] == TEST[481]
# TRAIN[5511] == TEST[481]
# TRAIN[5524] == TEST[481]
# TRAIN[5542] == TEST[481]
# TRAIN[5645] == TEST[481]
# TRAIN[5653] == TEST[481]
# TRAIN[5654] == TEST[481]
# TRAIN[5795] == TEST[481]
# TRAIN[6083] == TEST[481]
# TRAIN[6092] == TEST[481]
# TRAIN[6123] == TEST[481]
# TRAIN[6139] == TEST[481]
# TRAIN[6458] == TEST[481]
# TRAIN[6475] == TEST[481]
# TRAIN[6784] == TEST[481]
# TRAIN[7092] == TEST[481]
# TRAIN[7119] == TEST[481]
# TRAIN[7244] == TEST[481]
# TRAIN[7255] == TEST[481]
# TRAIN[7273] == TEST[481]
# TRAIN[7514] == TEST[481]
# TRAIN[7686] == TEST[481]
# TRAIN[8012] == TEST[481]
# TRAIN[8023] == TEST[481]
# TRAIN[8085] == TEST[481]
# TRAIN[8131] == TEST[481]
# TRAIN[8145] == TEST[481]
# TRAIN[8148] == TEST[481]
# TRAIN[8165] == TEST[481]
# TRAIN[8240] == TEST[481]
# TRAIN[8290] == TEST[481]
# TRAIN[8332] == TEST[481]
# TRAIN[8520] == TEST[481]
# TRAIN[8713] == TEST[481]
# TRAIN[8813] == TEST[481]
# TRAIN[8815] == TEST[481]
# TRAIN[8931] == TEST[481]
# TRAIN[9013] == TEST[481]
# TRAIN[9204] == TEST[481]
# TRAIN[9278] == TEST[481]
# TRAIN[9341] == TEST[481]
# TRAIN[9362] == TEST[481]
# TRAIN[9414] == TEST[481]
# TRAIN[9606] == TEST[481]
# TRAIN[9640] == TEST[481]
# TRAIN[9786] == TEST[481]
# TRAIN[9816] == TEST[481]
# TRAIN[9869] == TEST[481]
# TRAIN[9960] == TEST[481]
# TRAIN[10136] == TEST[481]
# TRAIN[10167] == TEST[481]
# TRAIN[10342] == TEST[481]
# TRAIN[10380] == TEST[481]
# TRAIN[10426] == TEST[481]
# TRAIN[10448] == TEST[481]
# TRAIN[10510] == TEST[481]
# TRAIN[10547] == TEST[481]
# TRAIN[10665] == TEST[481]
# TRAIN[10681] == TEST[481]
# TRAIN[10716] == TEST[481]
# TRAIN[10722] == TEST[481]
# TRAIN[10994] == TEST[481]
# TRAIN[10996] == TEST[481]
# TRAIN[11150] == TEST[481]
# TRAIN[11232] == TEST[481]
# TRAIN[11354] == TEST[481]
# TRAIN[11460] == TEST[481]
# TRAIN[11575] == TEST[481]
# TRAIN[11727] == TEST[481]
# TRAIN[11898] == TEST[481]
# TRAIN[12362] == TEST[481]
# TRAIN[12451] == TEST[481]
# TRAIN[12669] == TEST[481]
# TRAIN[12738] == TEST[481]
# TRAIN[12954] == TEST[481]
# TRAIN[12984] == TEST[481]
# TRAIN[12986] == TEST[481]
# TRAIN[13230] == TEST[481]
# TRAIN[13430] == TEST[481]
# TRAIN[13523] == TEST[481]
# TRAIN[13592] == TEST[481]
# TRAIN[13777] == TEST[481]
# TRAIN[13789] == TEST[481]
# TRAIN[13855] == TEST[481]
# TRAIN[13995] == TEST[481]
# TRAIN[14054] == TEST[481]
# TRAIN[14111] == TEST[481]
# TRAIN[14168] == TEST[481]
# TRAIN[14274] == TEST[481]
# TRAIN[14415] == TEST[481]
# TRAIN[14768] == TEST[481]
# TRAIN[14777] == TEST[481]
# TRAIN[15372] == TEST[481]
# TRAIN[15394] == TEST[481]
# TRAIN[15450] == TEST[481]
# TRAIN[15466] == TEST[481]
# TRAIN[15481] == TEST[481]
# TRAIN[15578] == TEST[481]
# TRAIN[15638] == TEST[481]
# TRAIN[15746] == TEST[481]
# TRAIN[15914] == TEST[481]
# TRAIN[15958] == TEST[481]
# TRAIN[15983] == TEST[481]
# TRAIN[16138] == TEST[481]
# TRAIN[16265] == TEST[481]
# TRAIN[16294] == TEST[481]
# TRAIN[16448] == TEST[481]
# TRAIN[16508] == TEST[481]
# TRAIN[16690] == TEST[481]
# TRAIN[16731] == TEST[481]
# TRAIN[16886] == TEST[481]
# TRAIN[17067] == TEST[481]
# TRAIN[17159] == TEST[481]
# TRAIN[17182] == TEST[481]
# TRAIN[17191] == TEST[481]
# TRAIN[17222] == TEST[481]
# TRAIN[17295] == TEST[481]
# TRAIN[17673] == TEST[481]
# TRAIN[17725] == TEST[481]
# TRAIN[17737] == TEST[481]
# TRAIN[17828] == TEST[481]
# TRAIN[17874] == TEST[481]
# TRAIN[18185] == TEST[481]
# TRAIN[18208] == TEST[481]
# TRAIN[18294] == TEST[481]
# TRAIN[18327] == TEST[481]
# TRAIN[18493] == TEST[481]
# TRAIN[18511] == TEST[481]
# TRAIN[18541] == TEST[481]
# TRAIN[18629] == TEST[481]
# TRAIN[18983] == TEST[481]
# TRAIN[19086] == TEST[481]
# TRAIN[19160] == TEST[481]
# TRAIN[19263] == TEST[481]
# TRAIN[19286] == TEST[481]
# TRAIN[19308] == TEST[481]
# TRAIN[19465] == TEST[481]
# TRAIN[19584] == TEST[481]
# TRAIN[19609] == TEST[481]
# TRAIN[19690] == TEST[481]
# TRAIN[19848] == TEST[481]
# TRAIN[4011] == TEST[543]
# TRAIN[26] == TEST[547]
# TRAIN[293] == TEST[547]
# TRAIN[445] == TEST[547]
# TRAIN[468] == TEST[547]
# TRAIN[543] == TEST[547]
# TRAIN[951] == TEST[547]
# TRAIN[1013] == TEST[547]
# TRAIN[1212] == TEST[547]
# TRAIN[1288] == TEST[547]
# TRAIN[1535] == TEST[547]
# TRAIN[1560] == TEST[547]
# TRAIN[1599] == TEST[547]
# TRAIN[1600] == TEST[547]
# TRAIN[1700] == TEST[547]
# TRAIN[1810] == TEST[547]
# TRAIN[1933] == TEST[547]
# TRAIN[1988] == TEST[547]
# TRAIN[1992] == TEST[547]
# TRAIN[2039] == TEST[547]
# TRAIN[2046] == TEST[547]
# TRAIN[2066] == TEST[547]
# TRAIN[2275] == TEST[547]
# TRAIN[2333] == TEST[547]
# TRAIN[2396] == TEST[547]
# TRAIN[2486] == TEST[547]
# TRAIN[2603] == TEST[547]
# TRAIN[2625] == TEST[547]
# TRAIN[2656] == TEST[547]
# TRAIN[2843] == TEST[547]
# TRAIN[2880] == TEST[547]
# TRAIN[2959] == TEST[547]
# TRAIN[3040] == TEST[547]
# TRAIN[3217] == TEST[547]
# TRAIN[3268] == TEST[547]
# TRAIN[3475] == TEST[547]
# TRAIN[3477] == TEST[547]
# TRAIN[3494] == TEST[547]
# TRAIN[3616] == TEST[547]
# TRAIN[3660] == TEST[547]
# TRAIN[3709] == TEST[547]
# TRAIN[3749] == TEST[547]
# TRAIN[3810] == TEST[547]
# TRAIN[3907] == TEST[547]
# TRAIN[3994] == TEST[547]
# TRAIN[4045] == TEST[547]
# TRAIN[4046] == TEST[547]
# TRAIN[4226] == TEST[547]
# TRAIN[4287] == TEST[547]
# TRAIN[4437] == TEST[547]
# TRAIN[4449] == TEST[547]
# TRAIN[4563] == TEST[547]
# TRAIN[4836] == TEST[547]
# TRAIN[4942] == TEST[547]
# TRAIN[4989] == TEST[547]
# TRAIN[5032] == TEST[547]
# TRAIN[5147] == TEST[547]
# TRAIN[5297] == TEST[547]
# TRAIN[5477] == TEST[547]
# TRAIN[5496] == TEST[547]
# TRAIN[5500] == TEST[547]
# TRAIN[5509] == TEST[547]
# TRAIN[5511] == TEST[547]
# TRAIN[5524] == TEST[547]
# TRAIN[5542] == TEST[547]
# TRAIN[5645] == TEST[547]
# TRAIN[5653] == TEST[547]
# TRAIN[5654] == TEST[547]
# TRAIN[5795] == TEST[547]
# TRAIN[6083] == TEST[547]
# TRAIN[6092] == TEST[547]
# TRAIN[6123] == TEST[547]
# TRAIN[6139] == TEST[547]
# TRAIN[6458] == TEST[547]
# TRAIN[6475] == TEST[547]
# TRAIN[6784] == TEST[547]
# TRAIN[7092] == TEST[547]
# TRAIN[7119] == TEST[547]
# TRAIN[7244] == TEST[547]
# TRAIN[7255] == TEST[547]
# TRAIN[7273] == TEST[547]
# TRAIN[7514] == TEST[547]
# TRAIN[7686] == TEST[547]
# TRAIN[8012] == TEST[547]
# TRAIN[8023] == TEST[547]
# TRAIN[8085] == TEST[547]
# TRAIN[8131] == TEST[547]
# TRAIN[8145] == TEST[547]
# TRAIN[8148] == TEST[547]
# TRAIN[8165] == TEST[547]
# TRAIN[8240] == TEST[547]
# TRAIN[8290] == TEST[547]
# TRAIN[8332] == TEST[547]
# TRAIN[8520] == TEST[547]
# TRAIN[8713] == TEST[547]
# TRAIN[8813] == TEST[547]
# TRAIN[8815] == TEST[547]
# TRAIN[8931] == TEST[547]
# TRAIN[9013] == TEST[547]
# TRAIN[9204] == TEST[547]
# TRAIN[9278] == TEST[547]
# TRAIN[9341] == TEST[547]
# TRAIN[9362] == TEST[547]
# TRAIN[9414] == TEST[547]
# TRAIN[9606] == TEST[547]
# TRAIN[9640] == TEST[547]
# TRAIN[9786] == TEST[547]
# TRAIN[9816] == TEST[547]
# TRAIN[9869] == TEST[547]
# TRAIN[9960] == TEST[547]
# TRAIN[10136] == TEST[547]
# TRAIN[10167] == TEST[547]
# TRAIN[10342] == TEST[547]
# TRAIN[10380] == TEST[547]
# TRAIN[10426] == TEST[547]
# TRAIN[10448] == TEST[547]
# TRAIN[10510] == TEST[547]
# TRAIN[10547] == TEST[547]
# TRAIN[10665] == TEST[547]
# TRAIN[10681] == TEST[547]
# TRAIN[10716] == TEST[547]
# TRAIN[10722] == TEST[547]
# TRAIN[10994] == TEST[547]
# TRAIN[10996] == TEST[547]
# TRAIN[11150] == TEST[547]
# TRAIN[11232] == TEST[547]
# TRAIN[11354] == TEST[547]
# TRAIN[11460] == TEST[547]
# TRAIN[11575] == TEST[547]
# TRAIN[11727] == TEST[547]
# TRAIN[11898] == TEST[547]
# TRAIN[12362] == TEST[547]
# TRAIN[12451] == TEST[547]
# TRAIN[12669] == TEST[547]
# TRAIN[12738] == TEST[547]
# TRAIN[12954] == TEST[547]
# TRAIN[12984] == TEST[547]
# TRAIN[12986] == TEST[547]
# TRAIN[13230] == TEST[547]
# TRAIN[13430] == TEST[547]
# TRAIN[13523] == TEST[547]
# TRAIN[13592] == TEST[547]
# TRAIN[13777] == TEST[547]
# TRAIN[13789] == TEST[547]
# TRAIN[13855] == TEST[547]
# TRAIN[13995] == TEST[547]
# TRAIN[14054] == TEST[547]
# TRAIN[14111] == TEST[547]
# TRAIN[14168] == TEST[547]
# TRAIN[14274] == TEST[547]
# TRAIN[14415] == TEST[547]
# TRAIN[14768] == TEST[547]
# TRAIN[14777] == TEST[547]
# TRAIN[15372] == TEST[547]
# TRAIN[15394] == TEST[547]
# TRAIN[15450] == TEST[547]
# TRAIN[15466] == TEST[547]
# TRAIN[15481] == TEST[547]
# TRAIN[15578] == TEST[547]
# TRAIN[15638] == TEST[547]
# TRAIN[15746] == TEST[547]
# TRAIN[15914] == TEST[547]
# TRAIN[15958] == TEST[547]
# TRAIN[15983] == TEST[547]
# TRAIN[16138] == TEST[547]
# TRAIN[16265] == TEST[547]
# TRAIN[16294] == TEST[547]
# TRAIN[16448] == TEST[547]
# TRAIN[16508] == TEST[547]
# TRAIN[16690] == TEST[547]
# TRAIN[16731] == TEST[547]
# TRAIN[16886] == TEST[547]
# TRAIN[17067] == TEST[547]
# TRAIN[17159] == TEST[547]
# TRAIN[17182] == TEST[547]
# TRAIN[17191] == TEST[547]
# TRAIN[17222] == TEST[547]
# TRAIN[17295] == TEST[547]
# TRAIN[17673] == TEST[547]
# TRAIN[17725] == TEST[547]
# TRAIN[17737] == TEST[547]
# TRAIN[17828] == TEST[547]
# TRAIN[17874] == TEST[547]
# TRAIN[18185] == TEST[547]
# TRAIN[18208] == TEST[547]
# TRAIN[18294] == TEST[547]
# TRAIN[18327] == TEST[547]
# TRAIN[18493] == TEST[547]
# TRAIN[18511] == TEST[547]
# TRAIN[18541] == TEST[547]
# TRAIN[18629] == TEST[547]
# TRAIN[18983] == TEST[547]
# TRAIN[19086] == TEST[547]
# TRAIN[19160] == TEST[547]
# TRAIN[19263] == TEST[547]
# TRAIN[19286] == TEST[547]
# TRAIN[19308] == TEST[547]
# TRAIN[19465] == TEST[547]
# TRAIN[19584] == TEST[547]
# TRAIN[19609] == TEST[547]
# TRAIN[19690] == TEST[547]
# TRAIN[19848] == TEST[547]
# TRAIN[6557] == TEST[563]
# TRAIN[26] == TEST[625]
# TRAIN[293] == TEST[625]
# TRAIN[445] == TEST[625]
# TRAIN[468] == TEST[625]
# TRAIN[543] == TEST[625]
# TRAIN[951] == TEST[625]
# TRAIN[1013] == TEST[625]
# TRAIN[1212] == TEST[625]
# TRAIN[1288] == TEST[625]
# TRAIN[1535] == TEST[625]
# TRAIN[1560] == TEST[625]
# TRAIN[1599] == TEST[625]
# TRAIN[1600] == TEST[625]
# TRAIN[1700] == TEST[625]
# TRAIN[1810] == TEST[625]
# TRAIN[1933] == TEST[625]
# TRAIN[1988] == TEST[625]
# TRAIN[1992] == TEST[625]
# TRAIN[2039] == TEST[625]
# TRAIN[2046] == TEST[625]
# TRAIN[2066] == TEST[625]
# TRAIN[2275] == TEST[625]
# TRAIN[2333] == TEST[625]
# TRAIN[2396] == TEST[625]
# TRAIN[2486] == TEST[625]
# TRAIN[2603] == TEST[625]
# TRAIN[2625] == TEST[625]
# TRAIN[2656] == TEST[625]
# TRAIN[2843] == TEST[625]
# TRAIN[2880] == TEST[625]
# TRAIN[2959] == TEST[625]
# TRAIN[3040] == TEST[625]
# TRAIN[3217] == TEST[625]
# TRAIN[3268] == TEST[625]
# TRAIN[3475] == TEST[625]
# TRAIN[3477] == TEST[625]
# TRAIN[3494] == TEST[625]
# TRAIN[3616] == TEST[625]
# TRAIN[3660] == TEST[625]
# TRAIN[3709] == TEST[625]
# TRAIN[3749] == TEST[625]
# TRAIN[3810] == TEST[625]
# TRAIN[3907] == TEST[625]
# TRAIN[3994] == TEST[625]
# TRAIN[4045] == TEST[625]
# TRAIN[4046] == TEST[625]
# TRAIN[4226] == TEST[625]
# TRAIN[4287] == TEST[625]
# TRAIN[4437] == TEST[625]
# TRAIN[4449] == TEST[625]
# TRAIN[4563] == TEST[625]
# TRAIN[4836] == TEST[625]
# TRAIN[4942] == TEST[625]
# TRAIN[4989] == TEST[625]
# TRAIN[5032] == TEST[625]
# TRAIN[5147] == TEST[625]
# TRAIN[5297] == TEST[625]
# TRAIN[5477] == TEST[625]
# TRAIN[5496] == TEST[625]
# TRAIN[5500] == TEST[625]
# TRAIN[5509] == TEST[625]
# TRAIN[5511] == TEST[625]
# TRAIN[5524] == TEST[625]
# TRAIN[5542] == TEST[625]
# TRAIN[5645] == TEST[625]
# TRAIN[5653] == TEST[625]
# TRAIN[5654] == TEST[625]
# TRAIN[5795] == TEST[625]
# TRAIN[6083] == TEST[625]
# TRAIN[6092] == TEST[625]
# TRAIN[6123] == TEST[625]
# TRAIN[6139] == TEST[625]
# TRAIN[6458] == TEST[625]
# TRAIN[6475] == TEST[625]
# TRAIN[6784] == TEST[625]
# TRAIN[7092] == TEST[625]
# TRAIN[7119] == TEST[625]
# TRAIN[7244] == TEST[625]
# TRAIN[7255] == TEST[625]
# TRAIN[7273] == TEST[625]
# TRAIN[7514] == TEST[625]
# TRAIN[7686] == TEST[625]
# TRAIN[8012] == TEST[625]
# TRAIN[8023] == TEST[625]
# TRAIN[8085] == TEST[625]
# TRAIN[8131] == TEST[625]
# TRAIN[8145] == TEST[625]
# TRAIN[8148] == TEST[625]
# TRAIN[8165] == TEST[625]
# TRAIN[8240] == TEST[625]
# TRAIN[8290] == TEST[625]
# TRAIN[8332] == TEST[625]
# TRAIN[8520] == TEST[625]
# TRAIN[8713] == TEST[625]
# TRAIN[8813] == TEST[625]
# TRAIN[8815] == TEST[625]
# TRAIN[8931] == TEST[625]
# TRAIN[9013] == TEST[625]
# TRAIN[9204] == TEST[625]
# TRAIN[9278] == TEST[625]
# TRAIN[9341] == TEST[625]
# TRAIN[9362] == TEST[625]
# TRAIN[9414] == TEST[625]
# TRAIN[9606] == TEST[625]
# TRAIN[9640] == TEST[625]
# TRAIN[9786] == TEST[625]
# TRAIN[9816] == TEST[625]
# TRAIN[9869] == TEST[625]
# TRAIN[9960] == TEST[625]
# TRAIN[10136] == TEST[625]
# TRAIN[10167] == TEST[625]
# TRAIN[10342] == TEST[625]
# TRAIN[10380] == TEST[625]
# TRAIN[10426] == TEST[625]
# TRAIN[10448] == TEST[625]
# TRAIN[10510] == TEST[625]
# TRAIN[10547] == TEST[625]
# TRAIN[10665] == TEST[625]
# TRAIN[10681] == TEST[625]
# TRAIN[10716] == TEST[625]
# TRAIN[10722] == TEST[625]
# TRAIN[10994] == TEST[625]
# TRAIN[10996] == TEST[625]
# TRAIN[11150] == TEST[625]
# TRAIN[11232] == TEST[625]
# TRAIN[11354] == TEST[625]
# TRAIN[11460] == TEST[625]
# TRAIN[11575] == TEST[625]
# TRAIN[11727] == TEST[625]
# TRAIN[11898] == TEST[625]
# TRAIN[12362] == TEST[625]
# TRAIN[12451] == TEST[625]
# TRAIN[12669] == TEST[625]
# TRAIN[12738] == TEST[625]
# TRAIN[12954] == TEST[625]
# TRAIN[12984] == TEST[625]
# TRAIN[12986] == TEST[625]
# TRAIN[13230] == TEST[625]
# TRAIN[13430] == TEST[625]
# TRAIN[13523] == TEST[625]
# TRAIN[13592] == TEST[625]
# TRAIN[13777] == TEST[625]
# TRAIN[13789] == TEST[625]
# TRAIN[13855] == TEST[625]
# TRAIN[13995] == TEST[625]
# TRAIN[14054] == TEST[625]
# TRAIN[14111] == TEST[625]
# TRAIN[14168] == TEST[625]
# TRAIN[14274] == TEST[625]
# TRAIN[14415] == TEST[625]
# TRAIN[14768] == TEST[625]
# TRAIN[14777] == TEST[625]
# TRAIN[15372] == TEST[625]
# TRAIN[15394] == TEST[625]
# TRAIN[15450] == TEST[625]
# TRAIN[15466] == TEST[625]
# TRAIN[15481] == TEST[625]
# TRAIN[15578] == TEST[625]
# TRAIN[15638] == TEST[625]
# TRAIN[15746] == TEST[625]
# TRAIN[15914] == TEST[625]
# TRAIN[15958] == TEST[625]
# TRAIN[15983] == TEST[625]
# TRAIN[16138] == TEST[625]
# TRAIN[16265] == TEST[625]
# TRAIN[16294] == TEST[625]
# TRAIN[16448] == TEST[625]
# TRAIN[16508] == TEST[625]
# TRAIN[16690] == TEST[625]
# TRAIN[16731] == TEST[625]
# TRAIN[16886] == TEST[625]
# TRAIN[17067] == TEST[625]
# TRAIN[17159] == TEST[625]
# TRAIN[17182] == TEST[625]
# TRAIN[17191] == TEST[625]
# TRAIN[17222] == TEST[625]
# TRAIN[17295] == TEST[625]
# TRAIN[17673] == TEST[625]
# TRAIN[17725] == TEST[625]
# TRAIN[17737] == TEST[625]
# TRAIN[17828] == TEST[625]
# TRAIN[17874] == TEST[625]
# TRAIN[18185] == TEST[625]
# TRAIN[18208] == TEST[625]
# TRAIN[18294] == TEST[625]
# TRAIN[18327] == TEST[625]
# TRAIN[18493] == TEST[625]
# TRAIN[18511] == TEST[625]
# TRAIN[18541] == TEST[625]
# TRAIN[18629] == TEST[625]
# TRAIN[18983] == TEST[625]
# TRAIN[19086] == TEST[625]
# TRAIN[19160] == TEST[625]
# TRAIN[19263] == TEST[625]
# TRAIN[19286] == TEST[625]
# TRAIN[19308] == TEST[625]
# TRAIN[19465] == TEST[625]
# TRAIN[19584] == TEST[625]
# TRAIN[19609] == TEST[625]
# TRAIN[19690] == TEST[625]
# TRAIN[19848] == TEST[625]
# TRAIN[26] == TEST[672]
# TRAIN[293] == TEST[672]
# TRAIN[445] == TEST[672]
# TRAIN[468] == TEST[672]
# TRAIN[543] == TEST[672]
# TRAIN[951] == TEST[672]
# TRAIN[1013] == TEST[672]
# TRAIN[1212] == TEST[672]
# TRAIN[1288] == TEST[672]
# TRAIN[1535] == TEST[672]
# TRAIN[1560] == TEST[672]
# TRAIN[1599] == TEST[672]
# TRAIN[1600] == TEST[672]
# TRAIN[1700] == TEST[672]
# TRAIN[1810] == TEST[672]
# TRAIN[1933] == TEST[672]
# TRAIN[1988] == TEST[672]
# TRAIN[1992] == TEST[672]
# TRAIN[2039] == TEST[672]
# TRAIN[2046] == TEST[672]
# TRAIN[2066] == TEST[672]
# TRAIN[2275] == TEST[672]
# TRAIN[2333] == TEST[672]
# TRAIN[2396] == TEST[672]
# TRAIN[2486] == TEST[672]
# TRAIN[2603] == TEST[672]
# TRAIN[2625] == TEST[672]
# TRAIN[2656] == TEST[672]
# TRAIN[2843] == TEST[672]
# TRAIN[2880] == TEST[672]
# TRAIN[2959] == TEST[672]
# TRAIN[3040] == TEST[672]
# TRAIN[3217] == TEST[672]
# TRAIN[3268] == TEST[672]
# TRAIN[3475] == TEST[672]
# TRAIN[3477] == TEST[672]
# TRAIN[3494] == TEST[672]
# TRAIN[3616] == TEST[672]
# TRAIN[3660] == TEST[672]
# TRAIN[3709] == TEST[672]
# TRAIN[3749] == TEST[672]
# TRAIN[3810] == TEST[672]
# TRAIN[3907] == TEST[672]
# TRAIN[3994] == TEST[672]
# TRAIN[4045] == TEST[672]
# TRAIN[4046] == TEST[672]
# TRAIN[4226] == TEST[672]
# TRAIN[4287] == TEST[672]
# TRAIN[4437] == TEST[672]
# TRAIN[4449] == TEST[672]
# TRAIN[4563] == TEST[672]
# TRAIN[4836] == TEST[672]
# TRAIN[4942] == TEST[672]
# TRAIN[4989] == TEST[672]
# TRAIN[5032] == TEST[672]
# TRAIN[5147] == TEST[672]
# TRAIN[5297] == TEST[672]
# TRAIN[5477] == TEST[672]
# TRAIN[5496] == TEST[672]
# TRAIN[5500] == TEST[672]
# TRAIN[5509] == TEST[672]
# TRAIN[5511] == TEST[672]
# TRAIN[5524] == TEST[672]
# TRAIN[5542] == TEST[672]
# TRAIN[5645] == TEST[672]
# TRAIN[5653] == TEST[672]
# TRAIN[5654] == TEST[672]
# TRAIN[5795] == TEST[672]
# TRAIN[6083] == TEST[672]
# TRAIN[6092] == TEST[672]
# TRAIN[6123] == TEST[672]
# TRAIN[6139] == TEST[672]
# TRAIN[6458] == TEST[672]
# TRAIN[6475] == TEST[672]
# TRAIN[6784] == TEST[672]
# ...
# TRAIN[17828] == TEST[761]
# TRAIN[17874] == TEST[761]
# TRAIN[18185] == TEST[761]
# TRAIN[18208] == TEST[761]
# TRAIN[18294] == TEST[761]
# TRAIN[18327] == TEST[761]
# TRAIN[18493] == TEST[761]
# TRAIN[18511] == TEST[761]
# TRAIN[18541] == TEST[761]
# TRAIN[18629] == TEST[761]
# TRAIN[18983] == TEST[761]
# TRAIN[19086] == TEST[761]
# TRAIN[19160] == TEST[761]
# TRAIN[19263] == TEST[761]
# TRAIN[19286] == TEST[761]
# TRAIN[19308] == TEST[761]
# TRAIN[19465] == TEST[761]
# TRAIN[19584] == TEST[761]
# TRAIN[19609] == TEST[761]
# TRAIN[19690] == TEST[761]
# TRAIN[19848] == TEST[761]
# TRAIN[26] == TEST[777]
# TRAIN[293] == TEST[777]
# TRAIN[445] == TEST[777]
# TRAIN[468] == TEST[777]
# TRAIN[543] == TEST[777]
# TRAIN[951] == TEST[777]
# TRAIN[1013] == TEST[777]
# TRAIN[1212] == TEST[777]
# TRAIN[1288] == TEST[777]
# TRAIN[1535] == TEST[777]
# TRAIN[1560] == TEST[777]
# TRAIN[1599] == TEST[777]
# TRAIN[1600] == TEST[777]
# TRAIN[1700] == TEST[777]
# TRAIN[1810] == TEST[777]
# TRAIN[1933] == TEST[777]
# TRAIN[1988] == TEST[777]
# TRAIN[1992] == TEST[777]
# TRAIN[2039] == TEST[777]
# TRAIN[2046] == TEST[777]
# TRAIN[2066] == TEST[777]
# TRAIN[2275] == TEST[777]
# TRAIN[2333] == TEST[777]
# TRAIN[2396] == TEST[777]
# TRAIN[2486] == TEST[777]
# TRAIN[2603] == TEST[777]
# TRAIN[2625] == TEST[777]
# TRAIN[2656] == TEST[777]
# TRAIN[2843] == TEST[777]
# TRAIN[2880] == TEST[777]
# TRAIN[2959] == TEST[777]
# TRAIN[3040] == TEST[777]
# TRAIN[3217] == TEST[777]
# TRAIN[3268] == TEST[777]
# TRAIN[3475] == TEST[777]
# TRAIN[3477] == TEST[777]
# TRAIN[3494] == TEST[777]
# TRAIN[3616] == TEST[777]
# TRAIN[3660] == TEST[777]
# TRAIN[3709] == TEST[777]
# TRAIN[3749] == TEST[777]
# TRAIN[3810] == TEST[777]
# TRAIN[3907] == TEST[777]
# TRAIN[3994] == TEST[777]
# TRAIN[4045] == TEST[777]
# TRAIN[4046] == TEST[777]
# TRAIN[4226] == TEST[777]
# TRAIN[4287] == TEST[777]
# TRAIN[4437] == TEST[777]
# TRAIN[4449] == TEST[777]
# TRAIN[4563] == TEST[777]
# TRAIN[4836] == TEST[777]
# TRAIN[4942] == TEST[777]
# TRAIN[4989] == TEST[777]
# TRAIN[5032] == TEST[777]
# TRAIN[5147] == TEST[777]
# TRAIN[5297] == TEST[777]
# TRAIN[5477] == TEST[777]
# TRAIN[5496] == TEST[777]
# TRAIN[5500] == TEST[777]
# TRAIN[5509] == TEST[777]
# TRAIN[5511] == TEST[777]
# TRAIN[5524] == TEST[777]
# TRAIN[5542] == TEST[777]
# TRAIN[5645] == TEST[777]
# TRAIN[5653] == TEST[777]
# TRAIN[5654] == TEST[777]
# TRAIN[5795] == TEST[777]
# TRAIN[6083] == TEST[777]
# TRAIN[6092] == TEST[777]
# TRAIN[6123] == TEST[777]
# TRAIN[6139] == TEST[777]
# TRAIN[6458] == TEST[777]
# TRAIN[6475] == TEST[777]
# TRAIN[6784] == TEST[777]
# TRAIN[7092] == TEST[777]
# TRAIN[7119] == TEST[777]
# TRAIN[7244] == TEST[777]
# TRAIN[7255] == TEST[777]
# TRAIN[7273] == TEST[777]
# TRAIN[7514] == TEST[777]
# TRAIN[7686] == TEST[777]
# TRAIN[8012] == TEST[777]
# TRAIN[8023] == TEST[777]
# TRAIN[8085] == TEST[777]
# TRAIN[8131] == TEST[777]
# TRAIN[8145] == TEST[777]
# TRAIN[8148] == TEST[777]
# TRAIN[8165] == TEST[777]
# TRAIN[8240] == TEST[777]
# TRAIN[8290] == TEST[777]
# TRAIN[8332] == TEST[777]
# TRAIN[8520] == TEST[777]
# TRAIN[8713] == TEST[777]
# TRAIN[8813] == TEST[777]
# TRAIN[8815] == TEST[777]
# TRAIN[8931] == TEST[777]
# TRAIN[9013] == TEST[777]
# TRAIN[9204] == TEST[777]
# TRAIN[9278] == TEST[777]
# TRAIN[9341] == TEST[777]
# TRAIN[9362] == TEST[777]
# TRAIN[9414] == TEST[777]
# TRAIN[9606] == TEST[777]
# TRAIN[9640] == TEST[777]
# TRAIN[9786] == TEST[777]
# TRAIN[9816] == TEST[777]
# TRAIN[9869] == TEST[777]
# TRAIN[9960] == TEST[777]
# TRAIN[10136] == TEST[777]
# TRAIN[10167] == TEST[777]
# TRAIN[10342] == TEST[777]
# TRAIN[10380] == TEST[777]
# TRAIN[10426] == TEST[777]
# TRAIN[10448] == TEST[777]
# TRAIN[10510] == TEST[777]
# TRAIN[10547] == TEST[777]
# TRAIN[10665] == TEST[777]
# TRAIN[10681] == TEST[777]
# TRAIN[10716] == TEST[777]
# TRAIN[10722] == TEST[777]
# TRAIN[10994] == TEST[777]
# TRAIN[10996] == TEST[777]
# TRAIN[11150] == TEST[777]
# TRAIN[11232] == TEST[777]
# TRAIN[11354] == TEST[777]
# TRAIN[11460] == TEST[777]
# TRAIN[11575] == TEST[777]
# TRAIN[11727] == TEST[777]
# TRAIN[11898] == TEST[777]
# TRAIN[12362] == TEST[777]
# TRAIN[12451] == TEST[777]
# TRAIN[12669] == TEST[777]
# TRAIN[12738] == TEST[777]
# TRAIN[12954] == TEST[777]
# TRAIN[12984] == TEST[777]
# TRAIN[12986] == TEST[777]
# TRAIN[13230] == TEST[777]
# TRAIN[13430] == TEST[777]
# TRAIN[13523] == TEST[777]
# TRAIN[13592] == TEST[777]
# TRAIN[13777] == TEST[777]
# TRAIN[13789] == TEST[777]
# TRAIN[13855] == TEST[777]
# TRAIN[13995] == TEST[777]
# TRAIN[14054] == TEST[777]
# TRAIN[14111] == TEST[777]
# TRAIN[14168] == TEST[777]
# TRAIN[14274] == TEST[777]
# TRAIN[14415] == TEST[777]
# TRAIN[14768] == TEST[777]
# TRAIN[14777] == TEST[777]
# TRAIN[15372] == TEST[777]
# TRAIN[15394] == TEST[777]
# TRAIN[15450] == TEST[777]
# TRAIN[15466] == TEST[777]
# TRAIN[15481] == TEST[777]
# TRAIN[15578] == TEST[777]
# TRAIN[15638] == TEST[777]
# TRAIN[15746] == TEST[777]
# TRAIN[15914] == TEST[777]
# TRAIN[15958] == TEST[777]
# TRAIN[15983] == TEST[777]
# TRAIN[16138] == TEST[777]
# TRAIN[16265] == TEST[777]
# TRAIN[16294] == TEST[777]
# TRAIN[16448] == TEST[777]
# TRAIN[16508] == TEST[777]
# TRAIN[16690] == TEST[777]
# TRAIN[16731] == TEST[777]
# TRAIN[16886] == TEST[777]
# TRAIN[17067] == TEST[777]
# TRAIN[17159] == TEST[777]
# TRAIN[17182] == TEST[777]
# TRAIN[17191] == TEST[777]
# TRAIN[17222] == TEST[777]
# TRAIN[17295] == TEST[777]
# TRAIN[17673] == TEST[777]
# TRAIN[17725] == TEST[777]
# TRAIN[17737] == TEST[777]
# TRAIN[17828] == TEST[777]
# TRAIN[17874] == TEST[777]
# TRAIN[18185] == TEST[777]
# TRAIN[18208] == TEST[777]
# TRAIN[18294] == TEST[777]
# TRAIN[18327] == TEST[777]
# TRAIN[18493] == TEST[777]
# TRAIN[18511] == TEST[777]
# TRAIN[18541] == TEST[777]
# TRAIN[18629] == TEST[777]
# TRAIN[18983] == TEST[777]
# TRAIN[19086] == TEST[777]
# TRAIN[19160] == TEST[777]
# TRAIN[19263] == TEST[777]
# TRAIN[19286] == TEST[777]
# TRAIN[19308] == TEST[777]
# TRAIN[19465] == TEST[777]
# TRAIN[19584] == TEST[777]
# TRAIN[19609] == TEST[777]
# TRAIN[19690] == TEST[777]
# TRAIN[19848] == TEST[777]
# TRAIN[12218] == TEST[797]
# TRAIN[26] == TEST[809]
# TRAIN[293] == TEST[809]
# TRAIN[445] == TEST[809]
# TRAIN[468] == TEST[809]
# TRAIN[543] == TEST[809]
# TRAIN[951] == TEST[809]
# TRAIN[1013] == TEST[809]
# TRAIN[1212] == TEST[809]
# TRAIN[1288] == TEST[809]
# TRAIN[1535] == TEST[809]
# TRAIN[1560] == TEST[809]
# TRAIN[1599] == TEST[809]
# TRAIN[1600] == TEST[809]
# TRAIN[1700] == TEST[809]
# TRAIN[1810] == TEST[809]
# TRAIN[1933] == TEST[809]
# TRAIN[1988] == TEST[809]
# TRAIN[1992] == TEST[809]
# TRAIN[2039] == TEST[809]
# TRAIN[2046] == TEST[809]
# TRAIN[2066] == TEST[809]
# TRAIN[2275] == TEST[809]
# TRAIN[2333] == TEST[809]
# TRAIN[2396] == TEST[809]
# TRAIN[2486] == TEST[809]
# TRAIN[2603] == TEST[809]
# TRAIN[2625] == TEST[809]
# TRAIN[2656] == TEST[809]
# TRAIN[2843] == TEST[809]
# TRAIN[2880] == TEST[809]
# TRAIN[2959] == TEST[809]
# TRAIN[3040] == TEST[809]
# TRAIN[3217] == TEST[809]
# TRAIN[3268] == TEST[809]
# TRAIN[3475] == TEST[809]
# TRAIN[3477] == TEST[809]
# TRAIN[3494] == TEST[809]
# TRAIN[3616] == TEST[809]
# TRAIN[3660] == TEST[809]
# TRAIN[3709] == TEST[809]
# TRAIN[3749] == TEST[809]
# TRAIN[3810] == TEST[809]
# TRAIN[3907] == TEST[809]
# TRAIN[3994] == TEST[809]
# TRAIN[4045] == TEST[809]
# TRAIN[4046] == TEST[809]
# TRAIN[4226] == TEST[809]
# TRAIN[4287] == TEST[809]
# TRAIN[4437] == TEST[809]
# TRAIN[4449] == TEST[809]
# TRAIN[4563] == TEST[809]
# TRAIN[4836] == TEST[809]
# TRAIN[4942] == TEST[809]
# TRAIN[4989] == TEST[809]
# TRAIN[5032] == TEST[809]
# TRAIN[5147] == TEST[809]
# TRAIN[5297] == TEST[809]
# TRAIN[5477] == TEST[809]
# TRAIN[5496] == TEST[809]
# TRAIN[5500] == TEST[809]
# TRAIN[5509] == TEST[809]
# TRAIN[5511] == TEST[809]
# TRAIN[5524] == TEST[809]
# TRAIN[5542] == TEST[809]
# TRAIN[5645] == TEST[809]
# TRAIN[5653] == TEST[809]
# TRAIN[5654] == TEST[809]
# TRAIN[5795] == TEST[809]
# TRAIN[6083] == TEST[809]
# TRAIN[6092] == TEST[809]
# TRAIN[6123] == TEST[809]
# TRAIN[6139] == TEST[809]
# TRAIN[6458] == TEST[809]
# TRAIN[6475] == TEST[809]
# TRAIN[6784] == TEST[809]
# TRAIN[7092] == TEST[809]
# TRAIN[7119] == TEST[809]
# TRAIN[7244] == TEST[809]
# TRAIN[7255] == TEST[809]
# TRAIN[7273] == TEST[809]
# TRAIN[7514] == TEST[809]
# TRAIN[7686] == TEST[809]
# TRAIN[8012] == TEST[809]
# TRAIN[8023] == TEST[809]
# TRAIN[8085] == TEST[809]
# TRAIN[8131] == TEST[809]
# TRAIN[8145] == TEST[809]
# TRAIN[8148] == TEST[809]
# TRAIN[8165] == TEST[809]
# TRAIN[8240] == TEST[809]
# TRAIN[8290] == TEST[809]
# TRAIN[8332] == TEST[809]
# TRAIN[8520] == TEST[809]
# TRAIN[8713] == TEST[809]
# TRAIN[8813] == TEST[809]
# TRAIN[8815] == TEST[809]
# TRAIN[8931] == TEST[809]
# TRAIN[9013] == TEST[809]
# TRAIN[9204] == TEST[809]
# TRAIN[9278] == TEST[809]
# TRAIN[9341] == TEST[809]
# TRAIN[9362] == TEST[809]
# TRAIN[9414] == TEST[809]
# TRAIN[9606] == TEST[809]
# TRAIN[9640] == TEST[809]
# TRAIN[9786] == TEST[809]
# TRAIN[9816] == TEST[809]
# TRAIN[9869] == TEST[809]
# TRAIN[9960] == TEST[809]
# TRAIN[10136] == TEST[809]
# TRAIN[10167] == TEST[809]
# TRAIN[10342] == TEST[809]
# TRAIN[10380] == TEST[809]
# TRAIN[10426] == TEST[809]
# TRAIN[10448] == TEST[809]
# TRAIN[10510] == TEST[809]
# TRAIN[10547] == TEST[809]
# TRAIN[10665] == TEST[809]
# TRAIN[10681] == TEST[809]
# TRAIN[10716] == TEST[809]
# TRAIN[10722] == TEST[809]
# TRAIN[10994] == TEST[809]
# TRAIN[10996] == TEST[809]
# TRAIN[11150] == TEST[809]
# TRAIN[11232] == TEST[809]
# TRAIN[11354] == TEST[809]
# TRAIN[11460] == TEST[809]
# TRAIN[11575] == TEST[809]
# TRAIN[11727] == TEST[809]
# TRAIN[11898] == TEST[809]
# TRAIN[12362] == TEST[809]
# TRAIN[12451] == TEST[809]
# TRAIN[12669] == TEST[809]
# TRAIN[12738] == TEST[809]
# TRAIN[12954] == TEST[809]
# TRAIN[12984] == TEST[809]
# TRAIN[12986] == TEST[809]
# TRAIN[13230] == TEST[809]
# TRAIN[13430] == TEST[809]
# TRAIN[13523] == TEST[809]
# TRAIN[13592] == TEST[809]
# TRAIN[13777] == TEST[809]
# TRAIN[13789] == TEST[809]
# TRAIN[13855] == TEST[809]
# TRAIN[13995] == TEST[809]
# TRAIN[14054] == TEST[809]
# TRAIN[14111] == TEST[809]
# TRAIN[14168] == TEST[809]
# TRAIN[14274] == TEST[809]
# TRAIN[14415] == TEST[809]
# TRAIN[14768] == TEST[809]
# TRAIN[14777] == TEST[809]
# TRAIN[15372] == TEST[809]
# TRAIN[15394] == TEST[809]
# TRAIN[15450] == TEST[809]
# TRAIN[15466] == TEST[809]
# TRAIN[15481] == TEST[809]
# TRAIN[15578] == TEST[809]
# TRAIN[15638] == TEST[809]
# TRAIN[15746] == TEST[809]
# TRAIN[15914] == TEST[809]
# TRAIN[15958] == TEST[809]
# TRAIN[15983] == TEST[809]
# TRAIN[16138] == TEST[809]
# TRAIN[16265] == TEST[809]
# TRAIN[16294] == TEST[809]
# TRAIN[16448] == TEST[809]
# TRAIN[16508] == TEST[809]
# TRAIN[16690] == TEST[809]
# TRAIN[16731] == TEST[809]
# TRAIN[16886] == TEST[809]
# TRAIN[17067] == TEST[809]
# TRAIN[17159] == TEST[809]
# TRAIN[17182] == TEST[809]
# TRAIN[17191] == TEST[809]
# TRAIN[17222] == TEST[809]
# TRAIN[17295] == TEST[809]
# TRAIN[17673] == TEST[809]
# TRAIN[17725] == TEST[809]
# TRAIN[17737] == TEST[809]
# TRAIN[17828] == TEST[809]
# TRAIN[17874] == TEST[809]
# TRAIN[18185] == TEST[809]
# TRAIN[18208] == TEST[809]
# TRAIN[18294] == TEST[809]
# TRAIN[18327] == TEST[809]
# TRAIN[18493] == TEST[809]
# TRAIN[18511] == TEST[809]
# TRAIN[18541] == TEST[809]
# TRAIN[18629] == TEST[809]
# TRAIN[18983] == TEST[809]
# TRAIN[19086] == TEST[809]
# TRAIN[19160] == TEST[809]
# TRAIN[19263] == TEST[809]
# TRAIN[19286] == TEST[809]
# TRAIN[19308] == TEST[809]
# TRAIN[19465] == TEST[809]
# TRAIN[19584] == TEST[809]
# TRAIN[19609] == TEST[809]
# TRAIN[19690] == TEST[809]
# TRAIN[19848] == TEST[809]
# TRAIN[11759] == TEST[848]
# TRAIN[26] == TEST[914]
# TRAIN[293] == TEST[914]
# TRAIN[445] == TEST[914]
# TRAIN[468] == TEST[914]
# TRAIN[543] == TEST[914]
# TRAIN[951] == TEST[914]
# TRAIN[1013] == TEST[914]
# TRAIN[1212] == TEST[914]
# TRAIN[1288] == TEST[914]
# TRAIN[1535] == TEST[914]
# TRAIN[1560] == TEST[914]
# TRAIN[1599] == TEST[914]
# TRAIN[1600] == TEST[914]
# TRAIN[1700] == TEST[914]
# TRAIN[1810] == TEST[914]
# TRAIN[1933] == TEST[914]
# TRAIN[1988] == TEST[914]
# TRAIN[1992] == TEST[914]
# TRAIN[2039] == TEST[914]
# TRAIN[2046] == TEST[914]
# TRAIN[2066] == TEST[914]
# TRAIN[2275] == TEST[914]
# TRAIN[2333] == TEST[914]
# TRAIN[2396] == TEST[914]
# TRAIN[2486] == TEST[914]
# TRAIN[2603] == TEST[914]
# TRAIN[2625] == TEST[914]
# TRAIN[2656] == TEST[914]
# TRAIN[2843] == TEST[914]
# TRAIN[2880] == TEST[914]
# TRAIN[2959] == TEST[914]
# TRAIN[3040] == TEST[914]
# TRAIN[3217] == TEST[914]
# TRAIN[3268] == TEST[914]
# TRAIN[3475] == TEST[914]
# TRAIN[3477] == TEST[914]
# TRAIN[3494] == TEST[914]
# TRAIN[3616] == TEST[914]
# TRAIN[3660] == TEST[914]
# TRAIN[3709] == TEST[914]
# TRAIN[3749] == TEST[914]
# TRAIN[3810] == TEST[914]
# TRAIN[3907] == TEST[914]
# TRAIN[3994] == TEST[914]
# TRAIN[4045] == TEST[914]
# TRAIN[4046] == TEST[914]
# TRAIN[4226] == TEST[914]
# TRAIN[4287] == TEST[914]
# TRAIN[4437] == TEST[914]
# TRAIN[4449] == TEST[914]
# TRAIN[4563] == TEST[914]
# TRAIN[4836] == TEST[914]
# TRAIN[4942] == TEST[914]
# TRAIN[4989] == TEST[914]
# TRAIN[5032] == TEST[914]
# TRAIN[5147] == TEST[914]
# TRAIN[5297] == TEST[914]
# TRAIN[5477] == TEST[914]
# TRAIN[5496] == TEST[914]
# TRAIN[5500] == TEST[914]
# TRAIN[5509] == TEST[914]
# TRAIN[5511] == TEST[914]
# TRAIN[5524] == TEST[914]
# TRAIN[5542] == TEST[914]
# TRAIN[5645] == TEST[914]
# TRAIN[5653] == TEST[914]
# TRAIN[5654] == TEST[914]
# TRAIN[5795] == TEST[914]
# TRAIN[6083] == TEST[914]
# TRAIN[6092] == TEST[914]
# TRAIN[6123] == TEST[914]
# TRAIN[6139] == TEST[914]
# TRAIN[6458] == TEST[914]
# TRAIN[6475] == TEST[914]
# TRAIN[6784] == TEST[914]
# TRAIN[7092] == TEST[914]
# TRAIN[7119] == TEST[914]
# TRAIN[7244] == TEST[914]
# TRAIN[7255] == TEST[914]
# TRAIN[7273] == TEST[914]
# TRAIN[7514] == TEST[914]
# TRAIN[7686] == TEST[914]
# TRAIN[8012] == TEST[914]
# TRAIN[8023] == TEST[914]
# TRAIN[8085] == TEST[914]
# TRAIN[8131] == TEST[914]
# TRAIN[8145] == TEST[914]
# TRAIN[8148] == TEST[914]
# TRAIN[8165] == TEST[914]
# TRAIN[8240] == TEST[914]
# TRAIN[8290] == TEST[914]
# TRAIN[8332] == TEST[914]
# TRAIN[8520] == TEST[914]
# TRAIN[8713] == TEST[914]
# TRAIN[8813] == TEST[914]
# TRAIN[8815] == TEST[914]
# TRAIN[8931] == TEST[914]
# TRAIN[9013] == TEST[914]
# TRAIN[9204] == TEST[914]
# TRAIN[9278] == TEST[914]
# TRAIN[9341] == TEST[914]
# TRAIN[9362] == TEST[914]
# TRAIN[9414] == TEST[914]
# TRAIN[9606] == TEST[914]
# TRAIN[9640] == TEST[914]
# TRAIN[9786] == TEST[914]
# TRAIN[9816] == TEST[914]
# TRAIN[9869] == TEST[914]
# TRAIN[9960] == TEST[914]
# TRAIN[10136] == TEST[914]
# TRAIN[10167] == TEST[914]
# TRAIN[10342] == TEST[914]
# TRAIN[10380] == TEST[914]
# TRAIN[10426] == TEST[914]
# TRAIN[10448] == TEST[914]
# TRAIN[10510] == TEST[914]
# TRAIN[10547] == TEST[914]
# TRAIN[10665] == TEST[914]
# TRAIN[10681] == TEST[914]
# TRAIN[10716] == TEST[914]
# TRAIN[10722] == TEST[914]
# TRAIN[10994] == TEST[914]
# TRAIN[10996] == TEST[914]
# TRAIN[11150] == TEST[914]
# TRAIN[11232] == TEST[914]
# TRAIN[11354] == TEST[914]
# TRAIN[11460] == TEST[914]
# TRAIN[11575] == TEST[914]
# TRAIN[11727] == TEST[914]
# TRAIN[11898] == TEST[914]
# TRAIN[12362] == TEST[914]
# TRAIN[12451] == TEST[914]
# TRAIN[12669] == TEST[914]
# TRAIN[12738] == TEST[914]
# TRAIN[12954] == TEST[914]
# TRAIN[12984] == TEST[914]
# TRAIN[12986] == TEST[914]
# TRAIN[13230] == TEST[914]
# TRAIN[13430] == TEST[914]
# TRAIN[13523] == TEST[914]
# TRAIN[13592] == TEST[914]
# TRAIN[13777] == TEST[914]
# TRAIN[13789] == TEST[914]
# TRAIN[13855] == TEST[914]
# TRAIN[13995] == TEST[914]
# TRAIN[14054] == TEST[914]
# TRAIN[14111] == TEST[914]
# TRAIN[14168] == TEST[914]
# TRAIN[14274] == TEST[914]
# TRAIN[14415] == TEST[914]
# TRAIN[14768] == TEST[914]
# TRAIN[14777] == TEST[914]
# TRAIN[15372] == TEST[914]
# TRAIN[15394] == TEST[914]
# TRAIN[15450] == TEST[914]
# TRAIN[15466] == TEST[914]
# TRAIN[15481] == TEST[914]
# TRAIN[15578] == TEST[914]
# TRAIN[15638] == TEST[914]
# TRAIN[15746] == TEST[914]
# TRAIN[15914] == TEST[914]
# TRAIN[15958] == TEST[914]
# TRAIN[15983] == TEST[914]
# TRAIN[16138] == TEST[914]
# TRAIN[16265] == TEST[914]
# TRAIN[16294] == TEST[914]
# TRAIN[16448] == TEST[914]
# TRAIN[16508] == TEST[914]
# TRAIN[16690] == TEST[914]
# TRAIN[16731] == TEST[914]
# TRAIN[16886] == TEST[914]
# TRAIN[17067] == TEST[914]
# TRAIN[17159] == TEST[914]
# TRAIN[17182] == TEST[914]
# TRAIN[17191] == TEST[914]
# TRAIN[17222] == TEST[914]
# TRAIN[17295] == TEST[914]
# TRAIN[17673] == TEST[914]
# TRAIN[17725] == TEST[914]
# TRAIN[17737] == TEST[914]
# TRAIN[17828] == TEST[914]
# TRAIN[17874] == TEST[914]
# TRAIN[18185] == TEST[914]
# TRAIN[18208] == TEST[914]
# TRAIN[18294] == TEST[914]
# TRAIN[18327] == TEST[914]
# TRAIN[18493] == TEST[914]
# TRAIN[18511] == TEST[914]
# TRAIN[18541] == TEST[914]
# TRAIN[18629] == TEST[914]
# TRAIN[18983] == TEST[914]
# TRAIN[19086] == TEST[914]
# TRAIN[19160] == TEST[914]
# TRAIN[19263] == TEST[914]
# TRAIN[19286] == TEST[914]
# TRAIN[19308] == TEST[914]
# TRAIN[19465] == TEST[914]
# TRAIN[19584] == TEST[914]
# TRAIN[19609] == TEST[914]
# TRAIN[19690] == TEST[914]
# TRAIN[19848] == TEST[914]
# TRAIN[16444] == TEST[918]
# TRAIN[5165] == TEST[980]

# %% [markdown]
# ---
# Problem 6
# ---------
#
# Let's get an idea of what an off-the-shelf classifier can give you on this data. It's always good to check that there is something to learn, and that it's a problem that is not so trivial that a canned solution solves it.
#
# Train a simple model on this data using 50, 100, 1000 and 5000 training samples. Hint: you can use the LogisticRegression model from sklearn.linear_model.
#
# Optional question: train an off-the-shelf model on all the data!
#
# ---

# %%
import os,pickle
data_root = '..'
import numpy as np
pickle_file = os.path.join(data_root, 'notMNIST.pickle')
f = open(pickle_file, 'rb')
pkl = pickle.load(f)
print(pkl.keys())
 #print(pkl['train_dataset'])
 #print(pkl['test_dataset'])
TRAIN_SIZE=20000
TEST_SIZE=1000
train_dataset = (pkl['train_dataset'][:TRAIN_SIZE]).reshape(TRAIN_SIZE,28*28)
test_dataset = (pkl['test_dataset'][:TEST_SIZE]).reshape(TEST_SIZE,28*28)
train_labels = (pkl['train_labels'][:TRAIN_SIZE]).reshape(TRAIN_SIZE)
test_labels = (pkl['test_labels'][:TEST_SIZE]).reshape(TEST_SIZE)

#print(train_dataset.shape)
#print(test_dataset[0])
#test_flattened = test_dataset.reshape(10,28*28)
#print(test_flattened.shape)
#print(test_flattened[0])
#train_flattened = train_dataset.flatten() 
#print(train_flattened.shape)
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(train_dataset,train_labels)
score = lr.score(test_dataset,test_labels )
print(score)
# Out:
# dict_keys(['train_dataset', 'train_labels', 'valid_dataset', 'valid_labels', 'test_dataset', 'test_labels'])
